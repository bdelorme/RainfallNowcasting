# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
project_id = 'acoustic-patrol-273919'
bucket_name = 'cs-231n-project-vdd'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://cs-231n-project-vdd/

# %%
# !gsutil -m cp -r /content/drive/My\ Drive/CS231N/Project/RainfallNowcasting/Radar/MeteoNet/Wrong_values/ gs://{bucket_name}/
# Out:
# Copying file:///content/drive/My Drive/CS231N/Project/RainfallNowcasting/Radar/MeteoNet/Wrong_values/arpege_10m_NW_20170826000000.grib [Content-Type=application/octet-stream]...
# Copying file:///content/drive/My Drive/CS231N/Project/RainfallNowcasting/Radar/MeteoNet/Wrong_values/arpege_2m_NW_20170826000000.grib [Content-Type=application/octet-stream]...
# Copying file:///content/drive/My Drive/CS231N/Project/RainfallNowcasting/Radar/MeteoNet/Wrong_values/arpege_10m_NW_20171205000000.grib [Content-Type=application/octet-stream]...
# Copying file:///content/drive/My Drive/CS231N/Project/RainfallNowcasting/Radar/MeteoNet/Wrong_values/arpege_PRECIP_NW_20171205000000.grib [Content-Type=application/octet-stream]...
# Copying file:///content/drive/My Drive/CS231N/Project/RainfallNowcasting/Radar/MeteoNet/Wrong_values/arpege_P_sea_level_NW_20171205000000.grib [Content-Type=application/octet-stream]...
# ...
