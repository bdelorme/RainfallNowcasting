# %%
# mounts Google Drive to the Colab VM
from google.colab import drive, files
drive.mount('/content/drive', force_remount=True)

# project github foldername
FOLDERNAME = '/content/drive/My Drive/CS231N/Project/RainfallNowcasting/MovingMNIST/'

# load python files from foldername
import sys
sys.path.append(FOLDERNAME)

# for auto-reloading external modules
# %load_ext autoreload
# %autoreload 2
# Out:
# Mounted at /content/drive
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Download Moving-MNIST dataset
# !wget 'http://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy'
# Out:
# --2020-05-18 21:53:47--  http://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 819200096 (781M)
# Saving to: ‘mnist_test_seq.npy.1’
#
# mnist_test_seq.npy. 100%[===================>] 781.25M  29.8MB/s    in 27s
#
# 2020-05-18 21:54:14 (28.7 MB/s) - ‘mnist_test_seq.npy.1’ saved [819200096/819200096]

# %%
# Useful libraries
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow_addons as tfa
import math as ma
# %matplotlib inline
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 3
np.set_printoptions(precision=2)

# %%
# Data processing
data = np.load('mnist_test_seq.npy')
data = data.swapaxes(0, 1) # swap frames and instances for tf handling
data = data[:500, :, :, :] # reduce memory and compute requirements by selecting a subsample
data = np.expand_dims(data, -1) # add channel dimension for tf handling (channel=1, ie grayscale)
train_data = data[:450, :, :, :]
val_data = data[450:, :, :, :]
train_data = train_data/np.max(data)
val_data = val_data/np.max(data)
N, F, H, W, C = data.shape # dims
print('dataset = '+str(data.shape)) # shape is [instance x frame x height x width x channel]
# Out:
# dataset = (500, 20, 64, 64, 1)

# %%
def MCNet_data(data, cutoff):
  X = data[:, :cutoff, :, :, :]
  y_MCNet = data[:, cutoff, :, :, :]
  X_MCNet_content = X[:, -1, :, :, :]
  # X_MCNet_motion = X[:, 1:, :, :, :] - X[:, :-1, :, :, :]
  X_MCNet_motion = X[:, :-1, :, :, :]
  return X_MCNet_motion, X_MCNet_content, y_MCNet
init_traj = 10
X_MCNet_motion, X_MCNet_content, y_MCNet = MCNet_data(train_data, init_traj)
X_val_MCNet_motion, X_val_MCNet_content, y_val_MCNet = MCNet_data(val_data, init_traj)
print("X_MCNet_motion is:", X_MCNet_motion.shape)
print("X_MCNet_content is:", X_MCNet_content.shape)
print("y_MCNet is:", y_MCNet.shape)
X_MCNet_motion = tf.cast(X_MCNet_motion, tf.float32)
X_MCNet_content = tf.cast(X_MCNet_content, tf.float32)
y_MCNet = tf.cast(y_MCNet, tf.float32)
X_val_MCNet_motion = tf.cast(X_val_MCNet_motion, tf.float32)
X_val_MCNet_content = tf.cast(X_val_MCNet_content, tf.float32)
y_val_MCNet = tf.cast(y_val_MCNet, tf.float32)
# Out:
# X_MCNet_motion is: (450, 9, 64, 64, 1)
# X_MCNet_content is: (450, 64, 64, 1)
# y_MCNet is: (450, 64, 64, 1)

# %%
# Custom metrics: SSIM, PSNR, POD, FAR

def ssim(y_gt, y_pred, max_val=1.):
  return tf.image.ssim(y_gt, y_pred, max_val)

def psnr(y_gt, y_pred, max_val=1.):
  return tf.image.psnr(y_gt, y_pred, max_val)

def cor(y_gt, y_pred):
  return tfp.stats.correlation(y_gt, y_pred, sample_axis=None, event_axis=None)

# %%
# Custom Loss
def mse_modified(y_gt, y_pred, max_val=.1):
  y_gt_pred_eq = tf.math.equal(y_gt, y_pred)
  y_pred_0 = tf.math.equal(y_pred, 0)
  y_both_0 = tf.math.logical_and(y_gt_pred_eq, y_pred_0)
  num_both_0 = tf.math.count_nonzero(y_both_0, dtype=tf.dtypes.float32)
  size_y = tf.size(y_gt, out_type=tf.dtypes.float32)
  return tf.keras.losses.MSE(y_gt, y_pred)*size_y/(size_y - num_both_0 + 1)


def ssim_loss(y_gt, y_pred, max_val=1.):
  return 1-tf.math.reduce_mean(tf.image.ssim(y_gt, y_pred, max_val))

def mse_mae_ssim_loss(y_gt, y_pred, max_val=1.):
  return ssim_loss(y_gt, y_pred, max_val) + \
         tf.keras.losses.MSE(y_gt, y_pred) + \
         tf.keras.losses.MAE(y_gt, y_pred)

def mse_binary_crossentropy(y_gt, y_pred, max_val=1.):
  return tf.keras.losses.MSE(y_gt, y_pred) + tf.keras.losses.binary_crossentropy(y_gt, y_pred)

# %%
# Our Model Architecture
def model_init():
    inputs_motion = tf.keras.Input(shape=[None, H, W, C])
    inputs_content = tf.keras.Input(shape=[H, W, C])

    inceptionv3 = tf.keras.applications.InceptionV3(include_top=False, input_shape=[2*H, 2*W, 3])
    inceptionv3.trainable = False

    l2_reg = tf.keras.regularizers.l2(l=0.001)

    # Motion Encoder
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.Conv2D(3, 3, activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2_reg))(inputs_motion)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.UpSampling2D(size=(2,2)))(x)
    x = tf.keras.layers.TimeDistributed(inceptionv3)(x) 
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.Reshape((8,8,-1)))(x)
    ME = tf.keras.layers.ConvLSTM2D(128, (7,7), activation='relu', padding='same', return_sequences=False, kernel_initializer='he_normal', kernel_regularizer=l2_reg)(x)

    # Content Encoder
    x = tf.keras.layers.Conv2D(3, 3, activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2_reg)(inputs_content)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.UpSampling2D(size=(2,2))(x)
    CE = inceptionv3(x)
    x = tf.keras.layers.BatchNormalization()(x)
    CE = tf.keras.layers.Reshape((8,8,128))(CE)

    # Combination layers
    concat = tf.keras.layers.Concatenate()([CE, ME])
    x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2_reg)(concat)
    x = tf.keras.layers.BatchNormalization()(x)

    # Decoder layers
    x = tf.keras.layers.UpSampling2D((2,2))(x)
    x = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2_reg)(x)
    x = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2_reg)(x) #new
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.UpSampling2D((2,2))(x)
    x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2_reg)(x)
    x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2_reg)(x) #new
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.UpSampling2D((2,2))(x)
    x = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2_reg)(x)
    x = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2_reg)(x)
    x = tf.keras.layers.BatchNormalization()(x)

    # Prediction
    preds = tf.keras.layers.Conv2D(1, 1, activation='sigmoid', padding='same', kernel_regularizer=l2_reg)(x) #sigmoid original
    return tf.keras.Model(inputs=[inputs_motion, inputs_content], outputs=preds)

# %%
# Learning rate step decay
def step_decay(epoch):
   initial_lrate = 0.001
   drop = 0.5
   epochs_drop = 30
   lrate = initial_lrate * ma.pow(drop, ma.floor((1+epoch)/epochs_drop))
   return lrate
lrate = tf.keras.callbacks.LearningRateScheduler(step_decay)

# %%
fl = tfa.losses.SigmoidFocalCrossEntropy()
model = model_init()
# Build optimizer
callbacks_list = [lrate]
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='binary_crossentropy',
              metrics=['acc', 'mse', 'binary_crossentropy',
                       ssim, psnr, cor,
                       tf.keras.metrics.Precision(name='prec'),
                       tf.keras.metrics.Recall(name='recall'),
                       tf.keras.metrics.FalseNegatives(name='FN'), 
                       tf.keras.metrics.FalsePositives(name='FP'),
                       tf.keras.metrics.TrueNegatives(name='TN'), 
                       tf.keras.metrics.TruePositives(name='TP')])
# Fit the model
history = model.fit([X_MCNet_motion, X_MCNet_content], y_MCNet, batch_size=30, epochs=200, validation_split=0.1)
# Out:
# Epoch 1/200
# 14/14 [==============================] - 13s 917ms/step - loss: 5.6863 - acc: 0.5464 - mse: 0.2551 - binary_crossentropy: 0.8022 - ssim: 0.0030 - psnr: 6.4850 - cor: 0.0356 - prec: 0.0809 - recall: 0.4726 - FN: 62504.0000 - FP: 635995.0000 - TN: 904364.0000 - TP: 56017.0000 - val_loss: 9.2430 - val_acc: 0.0806 - val_mse: 0.8374 - val_binary_crossentropy: 4.7411 - val_ssim: 0.0013 - val_psnr: 0.7718 - val_cor: 0.0824 - val_prec: 0.0796 - val_recall: 1.0000 - val_FN: 0.0000e+00 - val_FP: 156488.0000 - val_TN: 14294.0000 - val_TP: 13538.0000
# Epoch 2/200
# 14/14 [==============================] - 9s 659ms/step - loss: 4.6786 - acc: 0.8362 - mse: 0.1888 - binary_crossentropy: 0.5825 - ssim: 0.0023 - psnr: 7.2712 - cor: 0.1120 - prec: 0.1182 - recall: 0.1739 - FN: 97911.0000 - FP: 153805.0000 - TN: 1386554.0000 - TP: 20610.0000 - val_loss: 5.6220 - val_acc: 0.0691 - val_mse: 0.6896 - val_binary_crossentropy: 2.0373 - val_ssim: 0.0015 - val_psnr: 1.6179 - val_cor: 0.1050 - val_prec: 0.0786 - val_recall: 1.0000 - val_FN: 0.0000e+00 - val_FP: 158609.0000 - val_TN: 12173.0000 - val_TP: 13538.0000
# Epoch 3/200
# 14/14 [==============================] - 9s 654ms/step - loss: 3.7103 - acc: 0.9235 - mse: 0.1545 - binary_crossentropy: 0.5115 - ssim: 0.0026 - psnr: 8.1260 - cor: 0.1663 - prec: 0.1591 - recall: 0.0135 - FN: 116919.0000 - FP: 8465.0000 - TN: 1531894.0000 - TP: 1602.0000 - val_loss: 3.9600 - val_acc: 0.2660 - val_mse: 0.4505 - val_binary_crossentropy: 1.2044 - val_ssim: 0.0028 - val_psnr: 3.5353 - val_cor: 0.1664 - val_prec: 0.0985 - val_recall: 0.9870 - val_FN: 176.0000 - val_FP: 122276.0000 - val_TN: 48506.0000 - val_TP: 13362.0000
# Epoch 4/200
# 14/14 [==============================] - 9s 648ms/step - loss: 2.9036 - acc: 0.9281 - mse: 0.1255 - binary_crossentropy: 0.4485 - ssim: 0.0029 - psnr: 9.0259 - cor: 0.1880 - prec: 0.1867 - recall: 0.0016 - FN: 118330.0000 - FP: 832.0000 - TN: 1539527.0000 - TP: 191.0000 - val_loss: 2.4868 - val_acc: 0.9266 - val_mse: 0.0915 - val_binary_crossentropy: 0.3667 - val_ssim: 0.0039 - val_psnr: 10.4124 - val_cor: 0.1996 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 5/200
# 14/14 [==============================] - 9s 643ms/step - loss: 2.2910 - acc: 0.9281 - mse: 0.1008 - binary_crossentropy: 0.3906 - ssim: 0.0034 - psnr: 9.9836 - cor: 0.2027 - prec: 0.2066 - recall: 0.0019 - FN: 118295.0000 - FP: 868.0000 - TN: 1539491.0000 - TP: 226.0000 - val_loss: 1.9634 - val_acc: 0.9266 - val_mse: 0.0680 - val_binary_crossentropy: 0.3062 - val_ssim: 0.0039 - val_psnr: 11.6998 - val_cor: 0.0850 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 6/200
# 14/14 [==============================] - 9s 639ms/step - loss: 1.8369 - acc: 0.9286 - mse: 0.0805 - binary_crossentropy: 0.3385 - ssim: 0.0041 - psnr: 10.9655 - cor: 0.2197 - prec: 0.0000e+00 - recall: 0.0000e+00 - FN: 118521.0000 - FP: 0.0000e+00 - TN: 1540359.0000 - TP: 0.0000e+00 - val_loss: 1.5985 - val_acc: 0.9266 - val_mse: 0.0585 - val_binary_crossentropy: 0.2763 - val_ssim: 0.0045 - val_psnr: 12.3688 - val_cor: 0.1343 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 7/200
# 14/14 [==============================] - 9s 638ms/step - loss: 1.5007 - acc: 0.9285 - mse: 0.0651 - binary_crossentropy: 0.2943 - ssim: 0.0048 - psnr: 11.8979 - cor: 0.2292 - prec: 0.0000e+00 - recall: 0.0000e+00 - FN: 118521.0000 - FP: 69.0000 - TN: 1540290.0000 - TP: 0.0000e+00 - val_loss: 1.3476 - val_acc: 0.9266 - val_mse: 0.0569 - val_binary_crossentropy: 0.2707 - val_ssim: 0.0047 - val_psnr: 12.4885 - val_cor: 0.1137 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 8/200
# 14/14 [==============================] - 9s 641ms/step - loss: 1.2494 - acc: 0.9286 - mse: 0.0546 - binary_crossentropy: 0.2590 - ssim: 0.0060 - psnr: 12.6654 - cor: 0.2399 - prec: 0.0000e+00 - recall: 0.0000e+00 - FN: 118521.0000 - FP: 5.0000 - TN: 1540354.0000 - TP: 0.0000e+00 - val_loss: 1.1238 - val_acc: 0.9266 - val_mse: 0.0468 - val_binary_crossentropy: 0.2306 - val_ssim: 0.0076 - val_psnr: 13.3918 - val_cor: 0.1194 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 9/200
# 14/14 [==============================] - 9s 643ms/step - loss: 1.0609 - acc: 0.9285 - mse: 0.0479 - binary_crossentropy: 0.2332 - ssim: 0.0073 - psnr: 13.2438 - cor: 0.2327 - prec: 0.0000e+00 - recall: 0.0000e+00 - FN: 118521.0000 - FP: 12.0000 - TN: 1540347.0000 - TP: 0.0000e+00 - val_loss: 0.9758 - val_acc: 0.9266 - val_mse: 0.0451 - val_binary_crossentropy: 0.2221 - val_ssim: 0.0090 - val_psnr: 13.5706 - val_cor: 0.0900 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 10/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.9165 - acc: 0.9286 - mse: 0.0438 - binary_crossentropy: 0.2138 - ssim: 0.0096 - psnr: 13.6472 - cor: 0.2407 - prec: 0.0000e+00 - recall: 0.0000e+00 - FN: 118521.0000 - FP: 0.0000e+00 - TN: 1540359.0000 - TP: 0.0000e+00 - val_loss: 0.8512 - val_acc: 0.9266 - val_mse: 0.0425 - val_binary_crossentropy: 0.2069 - val_ssim: 0.0157 - val_psnr: 13.8614 - val_cor: 0.0777 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 11/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.8049 - acc: 0.9285 - mse: 0.0416 - binary_crossentropy: 0.2013 - ssim: 0.0126 - psnr: 13.8908 - cor: 0.2394 - prec: 0.3395 - recall: 4.6405e-04 - FN: 118466.0000 - FP: 107.0000 - TN: 1540252.0000 - TP: 55.0000 - val_loss: 0.7602 - val_acc: 0.9266 - val_mse: 0.0421 - val_binary_crossentropy: 0.2032 - val_ssim: 0.0286 - val_psnr: 13.9325 - val_cor: 0.0213 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 12/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.7151 - acc: 0.9286 - mse: 0.0399 - binary_crossentropy: 0.1908 - ssim: 0.0162 - psnr: 14.0768 - cor: 0.2506 - prec: 0.0000e+00 - recall: 0.0000e+00 - FN: 118521.0000 - FP: 0.0000e+00 - TN: 1540359.0000 - TP: 0.0000e+00 - val_loss: 0.6884 - val_acc: 0.9266 - val_mse: 0.0420 - val_binary_crossentropy: 0.2020 - val_ssim: 0.0305 - val_psnr: 13.9471 - val_cor: 0.1129 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 13/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.6433 - acc: 0.9285 - mse: 0.0389 - binary_crossentropy: 0.1838 - ssim: 0.0221 - psnr: 14.1952 - cor: 0.2651 - prec: 0.5653 - recall: 0.0019 - FN: 118296.0000 - FP: 173.0000 - TN: 1540186.0000 - TP: 225.0000 - val_loss: 0.6363 - val_acc: 0.9266 - val_mse: 0.0424 - val_binary_crossentropy: 0.2079 - val_ssim: 0.0669 - val_psnr: 13.9118 - val_cor: 0.0058 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 14/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.5855 - acc: 0.9282 - mse: 0.0383 - binary_crossentropy: 0.1791 - ssim: 0.0280 - psnr: 14.2755 - cor: 0.2692 - prec: 0.4782 - recall: 0.0044 - FN: 117994.0000 - FP: 575.0000 - TN: 1539784.0000 - TP: 527.0000 - val_loss: 0.5850 - val_acc: 0.9266 - val_mse: 0.0422 - val_binary_crossentropy: 0.2042 - val_ssim: 0.0481 - val_psnr: 13.9346 - val_cor: 0.0949 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 15/200
# 14/14 [==============================] - 9s 647ms/step - loss: 0.5343 - acc: 0.9285 - mse: 0.0373 - binary_crossentropy: 0.1723 - ssim: 0.0374 - psnr: 14.3964 - cor: 0.3019 - prec: 0.5652 - recall: 5.4843e-04 - FN: 118456.0000 - FP: 50.0000 - TN: 1540309.0000 - TP: 65.0000 - val_loss: 0.5548 - val_acc: 0.9266 - val_mse: 0.0428 - val_binary_crossentropy: 0.2151 - val_ssim: 0.1129 - val_psnr: 13.8756 - val_cor: 0.0012 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 16/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.4929 - acc: 0.9281 - mse: 0.0371 - binary_crossentropy: 0.1697 - ssim: 0.0462 - psnr: 14.4229 - cor: 0.3093 - prec: 0.5555 - recall: 0.0082 - FN: 117545.0000 - FP: 781.0000 - TN: 1539578.0000 - TP: 976.0000 - val_loss: 0.5164 - val_acc: 0.9266 - val_mse: 0.0427 - val_binary_crossentropy: 0.2124 - val_ssim: 0.1011 - val_psnr: 13.8886 - val_cor: 0.1360 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 17/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.4533 - acc: 0.9280 - mse: 0.0360 - binary_crossentropy: 0.1630 - ssim: 0.0628 - psnr: 14.5658 - cor: 0.3457 - prec: 0.5533 - recall: 0.0112 - FN: 117192.0000 - FP: 1073.0000 - TN: 1539286.0000 - TP: 1329.0000 - val_loss: 0.4920 - val_acc: 0.9266 - val_mse: 0.0430 - val_binary_crossentropy: 0.2180 - val_ssim: 0.1312 - val_psnr: 13.8628 - val_cor: -0.0125 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 18/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.4215 - acc: 0.9279 - mse: 0.0355 - binary_crossentropy: 0.1597 - ssim: 0.0787 - psnr: 14.6331 - cor: 0.3598 - prec: 0.6335 - recall: 0.0174 - FN: 116455.0000 - FP: 1195.0000 - TN: 1539164.0000 - TP: 2066.0000 - val_loss: 0.4657 - val_acc: 0.9266 - val_mse: 0.0430 - val_binary_crossentropy: 0.2180 - val_ssim: 0.1306 - val_psnr: 13.8629 - val_cor: 0.0337 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 19/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.4024 - acc: 0.9265 - mse: 0.0364 - binary_crossentropy: 0.1623 - ssim: 0.0915 - psnr: 14.5224 - cor: 0.3362 - prec: 0.5091 - recall: 0.0305 - FN: 114903.0000 - FP: 3489.0000 - TN: 1536870.0000 - TP: 3618.0000 - val_loss: 0.4458 - val_acc: 0.9266 - val_mse: 0.0426 - val_binary_crossentropy: 0.2110 - val_ssim: 0.0859 - val_psnr: 13.8949 - val_cor: 0.0354 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 20/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.3969 - acc: 0.9273 - mse: 0.0367 - binary_crossentropy: 0.1651 - ssim: 0.0993 - psnr: 14.4851 - cor: 0.3123 - prec: 0.5038 - recall: 0.0189 - FN: 116282.0000 - FP: 2205.0000 - TN: 1538154.0000 - TP: 2239.0000 - val_loss: 0.4377 - val_acc: 0.9266 - val_mse: 0.0425 - val_binary_crossentropy: 0.2118 - val_ssim: 0.1308 - val_psnr: 13.9012 - val_cor: 0.0892 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 21/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.3783 - acc: 0.9282 - mse: 0.0365 - binary_crossentropy: 0.1629 - ssim: 0.1050 - psnr: 14.5030 - cor: 0.3153 - prec: 0.5951 - recall: 0.0075 - FN: 117629.0000 - FP: 607.0000 - TN: 1539752.0000 - TP: 892.0000 - val_loss: 0.4229 - val_acc: 0.9266 - val_mse: 0.0430 - val_binary_crossentropy: 0.2217 - val_ssim: 0.2162 - val_psnr: 13.8527 - val_cor: 0.1263 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 22/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.3480 - acc: 0.9279 - mse: 0.0356 - binary_crossentropy: 0.1572 - ssim: 0.1178 - psnr: 14.6190 - cor: 0.3499 - prec: 0.5417 - recall: 0.0121 - FN: 117085.0000 - FP: 1215.0000 - TN: 1539144.0000 - TP: 1436.0000 - val_loss: 0.4194 - val_acc: 0.9266 - val_mse: 0.0437 - val_binary_crossentropy: 0.2401 - val_ssim: 0.3035 - val_psnr: 13.7941 - val_cor: -0.0475 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 23/200
# 14/14 [==============================] - 9s 647ms/step - loss: 0.3220 - acc: 0.9273 - mse: 0.0339 - binary_crossentropy: 0.1483 - ssim: 0.1463 - psnr: 14.8402 - cor: 0.4032 - prec: 0.5788 - recall: 0.0257 - FN: 115473.0000 - FP: 2218.0000 - TN: 1538141.0000 - TP: 3048.0000 - val_loss: 0.4104 - val_acc: 0.9266 - val_mse: 0.0437 - val_binary_crossentropy: 0.2404 - val_ssim: 0.3087 - val_psnr: 13.7934 - val_cor: -0.0545 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 24/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.3105 - acc: 0.9262 - mse: 0.0334 - binary_crossentropy: 0.1444 - ssim: 0.1673 - psnr: 14.9289 - cor: 0.4250 - prec: 0.5837 - recall: 0.0487 - FN: 112752.0000 - FP: 4114.0000 - TN: 1536245.0000 - TP: 5769.0000 - val_loss: 0.3910 - val_acc: 0.9266 - val_mse: 0.0434 - val_binary_crossentropy: 0.2299 - val_ssim: 0.2196 - val_psnr: 13.8208 - val_cor: -0.0442 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 25/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.3002 - acc: 0.9267 - mse: 0.0326 - binary_crossentropy: 0.1399 - ssim: 0.1951 - psnr: 15.0056 - cor: 0.4501 - prec: 0.5633 - recall: 0.0351 - FN: 114365.0000 - FP: 3222.0000 - TN: 1537137.0000 - TP: 4156.0000 - val_loss: 0.3935 - val_acc: 0.9266 - val_mse: 0.0436 - val_binary_crossentropy: 0.2372 - val_ssim: 0.2798 - val_psnr: 13.8009 - val_cor: -0.0481 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 26/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.2842 - acc: 0.9270 - mse: 0.0313 - binary_crossentropy: 0.1344 - ssim: 0.2234 - psnr: 15.1779 - cor: 0.4793 - prec: 0.6516 - recall: 0.0427 - FN: 113458.0000 - FP: 2707.0000 - TN: 1537652.0000 - TP: 5063.0000 - val_loss: 0.3728 - val_acc: 0.9266 - val_mse: 0.0434 - val_binary_crossentropy: 0.2312 - val_ssim: 0.2669 - val_psnr: 13.8177 - val_cor: 0.1683 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 27/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.2685 - acc: 0.9262 - mse: 0.0309 - binary_crossentropy: 0.1332 - ssim: 0.2455 - psnr: 15.2391 - cor: 0.4862 - prec: 0.6362 - recall: 0.0611 - FN: 111285.0000 - FP: 4137.0000 - TN: 1536222.0000 - TP: 7236.0000 - val_loss: 0.3766 - val_acc: 0.9266 - val_mse: 0.0438 - val_binary_crossentropy: 0.2456 - val_ssim: 0.3571 - val_psnr: 13.7826 - val_cor: -0.0375 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 28/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.2579 - acc: 0.9266 - mse: 0.0303 - binary_crossentropy: 0.1288 - ssim: 0.2748 - psnr: 15.3216 - cor: 0.5011 - prec: 0.6423 - recall: 0.0554 - FN: 111950.0000 - FP: 3659.0000 - TN: 1536700.0000 - TP: 6571.0000 - val_loss: 0.3719 - val_acc: 0.9266 - val_mse: 0.0438 - val_binary_crossentropy: 0.2474 - val_ssim: 0.3813 - val_psnr: 13.7814 - val_cor: 0.0336 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 29/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.2507 - acc: 0.9268 - mse: 0.0305 - binary_crossentropy: 0.1293 - ssim: 0.2933 - psnr: 15.3071 - cor: 0.4980 - prec: 0.6562 - recall: 0.0494 - FN: 112664.0000 - FP: 3068.0000 - TN: 1537291.0000 - TP: 5857.0000 - val_loss: 0.3594 - val_acc: 0.9266 - val_mse: 0.0437 - val_binary_crossentropy: 0.2412 - val_ssim: 0.3434 - val_psnr: 13.7969 - val_cor: 0.0551 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 30/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.2445 - acc: 0.9265 - mse: 0.0308 - binary_crossentropy: 0.1305 - ssim: 0.2954 - psnr: 15.2606 - cor: 0.4882 - prec: 0.6176 - recall: 0.0502 - FN: 112576.0000 - FP: 3681.0000 - TN: 1536678.0000 - TP: 5945.0000 - val_loss: 0.3650 - val_acc: 0.9266 - val_mse: 0.0440 - val_binary_crossentropy: 0.2563 - val_ssim: 0.4397 - val_psnr: 13.7656 - val_cor: -0.0437 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 31/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.2315 - acc: 0.9262 - mse: 0.0298 - binary_crossentropy: 0.1257 - ssim: 0.3241 - psnr: 15.3931 - cor: 0.5127 - prec: 0.6469 - recall: 0.0638 - FN: 110954.0000 - FP: 4130.0000 - TN: 1536229.0000 - TP: 7567.0000 - val_loss: 0.3513 - val_acc: 0.9266 - val_mse: 0.0438 - val_binary_crossentropy: 0.2475 - val_ssim: 0.3799 - val_psnr: 13.7811 - val_cor: 0.0126 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 32/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.2605 - acc: 0.9255 - mse: 0.0350 - binary_crossentropy: 0.1514 - ssim: 0.2817 - psnr: 14.7353 - cor: 0.3873 - prec: 0.5088 - recall: 0.0456 - FN: 113118.0000 - FP: 5216.0000 - TN: 1535143.0000 - TP: 5403.0000 - val_loss: 0.3450 - val_acc: 0.9266 - val_mse: 0.0432 - val_binary_crossentropy: 0.2285 - val_ssim: 0.3479 - val_psnr: 13.8373 - val_cor: 0.1650 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 33/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.2681 - acc: 0.9272 - mse: 0.0347 - binary_crossentropy: 0.1502 - ssim: 0.2671 - psnr: 14.7387 - cor: 0.3780 - prec: 0.5294 - recall: 0.0226 - FN: 115848.0000 - FP: 2376.0000 - TN: 1537983.0000 - TP: 2673.0000 - val_loss: 0.2992 - val_acc: 0.9266 - val_mse: 0.0402 - val_binary_crossentropy: 0.1830 - val_ssim: 0.1869 - val_psnr: 14.1505 - val_cor: 0.2827 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 34/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.2469 - acc: 0.9261 - mse: 0.0321 - binary_crossentropy: 0.1360 - ssim: 0.3032 - psnr: 15.0865 - cor: 0.4600 - prec: 0.6008 - recall: 0.0551 - FN: 111995.0000 - FP: 4337.0000 - TN: 1536022.0000 - TP: 6526.0000 - val_loss: 0.2794 - val_acc: 0.9266 - val_mse: 0.0393 - val_binary_crossentropy: 0.1751 - val_ssim: 0.1334 - val_psnr: 14.2339 - val_cor: 0.3005 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 35/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.2228 - acc: 0.9261 - mse: 0.0297 - binary_crossentropy: 0.1243 - ssim: 0.3488 - psnr: 15.4161 - cor: 0.5146 - prec: 0.6743 - recall: 0.0787 - FN: 109198.0000 - FP: 4504.0000 - TN: 1535855.0000 - TP: 9323.0000 - val_loss: 0.2854 - val_acc: 0.9266 - val_mse: 0.0414 - val_binary_crossentropy: 0.1944 - val_ssim: 0.2156 - val_psnr: 14.0205 - val_cor: 0.3009 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 36/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.2054 - acc: 0.9256 - mse: 0.0288 - binary_crossentropy: 0.1200 - ssim: 0.3795 - psnr: 15.5529 - cor: 0.5355 - prec: 0.6597 - recall: 0.0875 - FN: 108148.0000 - FP: 5352.0000 - TN: 1535007.0000 - TP: 10373.0000 - val_loss: 0.3206 - val_acc: 0.9266 - val_mse: 0.0435 - val_binary_crossentropy: 0.2414 - val_ssim: 0.4835 - val_psnr: 13.8046 - val_cor: 0.2432 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 37/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.1961 - acc: 0.9259 - mse: 0.0288 - binary_crossentropy: 0.1195 - ssim: 0.3897 - psnr: 15.5325 - cor: 0.5388 - prec: 0.6634 - recall: 0.0802 - FN: 109018.0000 - FP: 4822.0000 - TN: 1535537.0000 - TP: 9503.0000 - val_loss: 0.2814 - val_acc: 0.9266 - val_mse: 0.0420 - val_binary_crossentropy: 0.2071 - val_ssim: 0.3519 - val_psnr: 13.9611 - val_cor: 0.2884 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 38/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.1879 - acc: 0.9253 - mse: 0.0280 - binary_crossentropy: 0.1152 - ssim: 0.4117 - psnr: 15.6583 - cor: 0.5564 - prec: 0.6595 - recall: 0.0976 - FN: 106950.0000 - FP: 5974.0000 - TN: 1534385.0000 - TP: 11571.0000 - val_loss: 0.3520 - val_acc: 0.9266 - val_mse: 0.0442 - val_binary_crossentropy: 0.2758 - val_ssim: 0.6097 - val_psnr: 13.7432 - val_cor: 0.0900 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 39/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.1961 - acc: 0.9264 - mse: 0.0280 - binary_crossentropy: 0.1147 - ssim: 0.4240 - psnr: 15.6613 - cor: 0.5567 - prec: 0.6719 - recall: 0.0700 - FN: 110224.0000 - FP: 4051.0000 - TN: 1536308.0000 - TP: 8297.0000 - val_loss: 0.3616 - val_acc: 0.9266 - val_mse: 0.0442 - val_binary_crossentropy: 0.2779 - val_ssim: 0.5921 - val_psnr: 13.7370 - val_cor: 0.0117 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 40/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.1908 - acc: 0.9249 - mse: 0.0271 - binary_crossentropy: 0.1105 - ssim: 0.4546 - psnr: 15.7913 - cor: 0.5768 - prec: 0.6661 - recall: 0.1092 - FN: 105580.0000 - FP: 6486.0000 - TN: 1533873.0000 - TP: 12941.0000 - val_loss: 0.3408 - val_acc: 0.9266 - val_mse: 0.0441 - val_binary_crossentropy: 0.2662 - val_ssim: 0.5123 - val_psnr: 13.7502 - val_cor: -0.0295 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 41/200
# 14/14 [==============================] - 9s 647ms/step - loss: 0.1780 - acc: 0.9254 - mse: 0.0265 - binary_crossentropy: 0.1081 - ssim: 0.4732 - psnr: 15.8887 - cor: 0.5901 - prec: 0.6713 - recall: 0.1051 - FN: 106061.0000 - FP: 6101.0000 - TN: 1534258.0000 - TP: 12460.0000 - val_loss: 0.3451 - val_acc: 0.9266 - val_mse: 0.0443 - val_binary_crossentropy: 0.2802 - val_ssim: 0.5874 - val_psnr: 13.7343 - val_cor: -0.0576 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 42/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.1665 - acc: 0.9244 - mse: 0.0258 - binary_crossentropy: 0.1049 - ssim: 0.4920 - psnr: 16.0025 - cor: 0.6038 - prec: 0.6806 - recall: 0.1381 - FN: 102152.0000 - FP: 7683.0000 - TN: 1532676.0000 - TP: 16369.0000 - val_loss: 0.3217 - val_acc: 0.9266 - val_mse: 0.0441 - val_binary_crossentropy: 0.2638 - val_ssim: 0.4841 - val_psnr: 13.7526 - val_cor: -0.1319 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 43/200
# 14/14 [==============================] - 9s 649ms/step - loss: 0.1588 - acc: 0.9244 - mse: 0.0255 - binary_crossentropy: 0.1032 - ssim: 0.5174 - psnr: 16.0632 - cor: 0.6097 - prec: 0.6855 - recall: 0.1412 - FN: 101791.0000 - FP: 7675.0000 - TN: 1532684.0000 - TP: 16730.0000 - val_loss: 0.3236 - val_acc: 0.9266 - val_mse: 0.0442 - val_binary_crossentropy: 0.2705 - val_ssim: 0.5411 - val_psnr: 13.7443 - val_cor: -0.0537 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 44/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.1554 - acc: 0.9226 - mse: 0.0259 - binary_crossentropy: 0.1039 - ssim: 0.5333 - psnr: 15.9865 - cor: 0.6108 - prec: 0.6583 - recall: 0.1788 - FN: 97333.0000 - FP: 10998.0000 - TN: 1529361.0000 - TP: 21188.0000 - val_loss: 0.3086 - val_acc: 0.9266 - val_mse: 0.0440 - val_binary_crossentropy: 0.2587 - val_ssim: 0.4462 - val_psnr: 13.7602 - val_cor: -0.1364 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 45/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.1520 - acc: 0.9248 - mse: 0.0255 - binary_crossentropy: 0.1030 - ssim: 0.5393 - psnr: 16.0631 - cor: 0.6084 - prec: 0.6869 - recall: 0.1294 - FN: 103185.0000 - FP: 6991.0000 - TN: 1533368.0000 - TP: 15336.0000 - val_loss: 0.3035 - val_acc: 0.9266 - val_mse: 0.0440 - val_binary_crossentropy: 0.2558 - val_ssim: 0.4616 - val_psnr: 13.7646 - val_cor: 0.1229 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 46/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.1481 - acc: 0.9243 - mse: 0.0252 - binary_crossentropy: 0.1014 - ssim: 0.5537 - psnr: 16.1045 - cor: 0.6145 - prec: 0.6800 - recall: 0.1451 - FN: 101320.0000 - FP: 8093.0000 - TN: 1532266.0000 - TP: 17201.0000 - val_loss: 0.3020 - val_acc: 0.9266 - val_mse: 0.0440 - val_binary_crossentropy: 0.2566 - val_ssim: 0.4563 - val_psnr: 13.7634 - val_cor: 0.1062 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 47/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.1442 - acc: 0.9240 - mse: 0.0248 - binary_crossentropy: 0.0997 - ssim: 0.5710 - psnr: 16.1794 - cor: 0.6234 - prec: 0.6757 - recall: 0.1491 - FN: 100853.0000 - FP: 8481.0000 - TN: 1531878.0000 - TP: 17668.0000 - val_loss: 0.3016 - val_acc: 0.9266 - val_mse: 0.0440 - val_binary_crossentropy: 0.2584 - val_ssim: 0.4569 - val_psnr: 13.7605 - val_cor: -0.0216 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 48/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.1421 - acc: 0.9246 - mse: 0.0247 - binary_crossentropy: 0.0995 - ssim: 0.5753 - psnr: 16.1917 - cor: 0.6233 - prec: 0.7010 - recall: 0.1420 - FN: 101689.0000 - FP: 7178.0000 - TN: 1533181.0000 - TP: 16832.0000 - val_loss: 0.2996 - val_acc: 0.9266 - val_mse: 0.0440 - val_binary_crossentropy: 0.2579 - val_ssim: 0.4577 - val_psnr: 13.7612 - val_cor: 0.0164 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 49/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.1407 - acc: 0.9239 - mse: 0.0248 - binary_crossentropy: 0.0997 - ssim: 0.5849 - psnr: 16.1844 - cor: 0.6226 - prec: 0.6894 - recall: 0.1569 - FN: 99923.0000 - FP: 8381.0000 - TN: 1531978.0000 - TP: 18598.0000 - val_loss: 0.2943 - val_acc: 0.9266 - val_mse: 0.0439 - val_binary_crossentropy: 0.2542 - val_ssim: 0.4353 - val_psnr: 13.7676 - val_cor: 0.0669 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 50/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.1378 - acc: 0.9237 - mse: 0.0245 - binary_crossentropy: 0.0985 - ssim: 0.5989 - psnr: 16.2214 - cor: 0.6269 - prec: 0.6833 - recall: 0.1606 - FN: 99492.0000 - FP: 8821.0000 - TN: 1531538.0000 - TP: 19029.0000 - val_loss: 0.2875 - val_acc: 0.9266 - val_mse: 0.0438 - val_binary_crossentropy: 0.2491 - val_ssim: 0.4290 - val_psnr: 13.7777 - val_cor: 0.1989 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 51/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.1359 - acc: 0.9241 - mse: 0.0244 - binary_crossentropy: 0.0979 - ssim: 0.5995 - psnr: 16.2357 - cor: 0.6289 - prec: 0.6986 - recall: 0.1622 - FN: 99297.0000 - FP: 8294.0000 - TN: 1532065.0000 - TP: 19224.0000 - val_loss: 0.2913 - val_acc: 0.9266 - val_mse: 0.0439 - val_binary_crossentropy: 0.2538 - val_ssim: 0.4533 - val_psnr: 13.7699 - val_cor: 0.1685 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 52/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.1349 - acc: 0.9239 - mse: 0.0244 - binary_crossentropy: 0.0980 - ssim: 0.6091 - psnr: 16.2485 - cor: 0.6323 - prec: 0.6980 - recall: 0.1694 - FN: 98444.0000 - FP: 8686.0000 - TN: 1531673.0000 - TP: 20077.0000 - val_loss: 0.2902 - val_acc: 0.9266 - val_mse: 0.0439 - val_binary_crossentropy: 0.2537 - val_ssim: 0.4562 - val_psnr: 13.7702 - val_cor: 0.1705 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 53/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.1351 - acc: 0.9230 - mse: 0.0248 - binary_crossentropy: 0.0988 - ssim: 0.6124 - psnr: 16.1841 - cor: 0.6273 - prec: 0.6776 - recall: 0.1821 - FN: 96943.0000 - FP: 10269.0000 - TN: 1530090.0000 - TP: 21578.0000 - val_loss: 0.2630 - val_acc: 0.9266 - val_mse: 0.0431 - val_binary_crossentropy: 0.2271 - val_ssim: 0.4009 - val_psnr: 13.8552 - val_cor: 0.2969 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 54/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.1333 - acc: 0.9245 - mse: 0.0243 - binary_crossentropy: 0.0975 - ssim: 0.6189 - psnr: 16.2584 - cor: 0.6318 - prec: 0.7007 - recall: 0.1504 - FN: 100699.0000 - FP: 7612.0000 - TN: 1532747.0000 - TP: 17822.0000 - val_loss: 0.2823 - val_acc: 0.9266 - val_mse: 0.0436 - val_binary_crossentropy: 0.2470 - val_ssim: 0.4704 - val_psnr: 13.7966 - val_cor: 0.2118 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 55/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.1310 - acc: 0.9218 - mse: 0.0241 - binary_crossentropy: 0.0962 - ssim: 0.6295 - psnr: 16.3157 - cor: 0.6405 - prec: 0.6954 - recall: 0.2421 - FN: 89828.0000 - FP: 12571.0000 - TN: 1527788.0000 - TP: 28693.0000 - val_loss: 0.2903 - val_acc: 0.9266 - val_mse: 0.0439 - val_binary_crossentropy: 0.2563 - val_ssim: 0.5283 - val_psnr: 13.7713 - val_cor: 0.2126 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 56/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.1294 - acc: 0.9238 - mse: 0.0239 - binary_crossentropy: 0.0956 - ssim: 0.6333 - psnr: 16.3466 - cor: 0.6384 - prec: 0.7096 - recall: 0.1873 - FN: 96319.0000 - FP: 9086.0000 - TN: 1531273.0000 - TP: 22202.0000 - val_loss: 0.2777 - val_acc: 0.9266 - val_mse: 0.0435 - val_binary_crossentropy: 0.2443 - val_ssim: 0.5069 - val_psnr: 13.8132 - val_cor: 0.2456 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 57/200
# 14/14 [==============================] - 9s 641ms/step - loss: 0.1290 - acc: 0.9233 - mse: 0.0239 - binary_crossentropy: 0.0959 - ssim: 0.6355 - psnr: 16.3382 - cor: 0.6385 - prec: 0.7085 - recall: 0.2030 - FN: 94456.0000 - FP: 9902.0000 - TN: 1530457.0000 - TP: 24065.0000 - val_loss: 0.2797 - val_acc: 0.9266 - val_mse: 0.0436 - val_binary_crossentropy: 0.2468 - val_ssim: 0.5137 - val_psnr: 13.7969 - val_cor: 0.2665 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 58/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.1269 - acc: 0.9232 - mse: 0.0234 - binary_crossentropy: 0.0942 - ssim: 0.6417 - psnr: 16.4395 - cor: 0.6499 - prec: 0.7153 - recall: 0.2092 - FN: 93727.0000 - FP: 9867.0000 - TN: 1530492.0000 - TP: 24794.0000 - val_loss: 0.2892 - val_acc: 0.9266 - val_mse: 0.0438 - val_binary_crossentropy: 0.2567 - val_ssim: 0.5438 - val_psnr: 13.7767 - val_cor: 0.2281 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 59/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.1261 - acc: 0.9222 - mse: 0.0234 - binary_crossentropy: 0.0936 - ssim: 0.6529 - psnr: 16.4193 - cor: 0.6509 - prec: 0.7043 - recall: 0.2355 - FN: 90608.0000 - FP: 11719.0000 - TN: 1528640.0000 - TP: 27913.0000 - val_loss: 0.2804 - val_acc: 0.9266 - val_mse: 0.0435 - val_binary_crossentropy: 0.2482 - val_ssim: 0.5798 - val_psnr: 13.8060 - val_cor: 0.2890 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 60/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.1263 - acc: 0.9230 - mse: 0.0235 - binary_crossentropy: 0.0944 - ssim: 0.6509 - psnr: 16.4174 - cor: 0.6488 - prec: 0.7176 - recall: 0.2219 - FN: 92218.0000 - FP: 10350.0000 - TN: 1530009.0000 - TP: 26303.0000 - val_loss: 0.2951 - val_acc: 0.9266 - val_mse: 0.0440 - val_binary_crossentropy: 0.2635 - val_ssim: 0.5980 - val_psnr: 13.7631 - val_cor: 0.2582 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 61/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.1245 - acc: 0.9223 - mse: 0.0232 - binary_crossentropy: 0.0932 - ssim: 0.6587 - psnr: 16.4622 - cor: 0.6574 - prec: 0.7096 - recall: 0.2425 - FN: 89776.0000 - FP: 11762.0000 - TN: 1528597.0000 - TP: 28745.0000 - val_loss: 0.2932 - val_acc: 0.9266 - val_mse: 0.0439 - val_binary_crossentropy: 0.2605 - val_ssim: 0.4974 - val_psnr: 13.7663 - val_cor: 0.1171 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 62/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.1352 - acc: 0.9218 - mse: 0.0238 - binary_crossentropy: 0.0954 - ssim: 0.6314 - psnr: 16.3750 - cor: 0.6479 - prec: 0.7106 - recall: 0.2632 - FN: 87324.0000 - FP: 12704.0000 - TN: 1527655.0000 - TP: 31197.0000 - val_loss: 0.2763 - val_acc: 0.9266 - val_mse: 0.0429 - val_binary_crossentropy: 0.2307 - val_ssim: 0.5074 - val_psnr: 13.8628 - val_cor: 0.2465 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 63/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.1375 - acc: 0.9221 - mse: 0.0230 - binary_crossentropy: 0.0923 - ssim: 0.6641 - psnr: 16.5103 - cor: 0.6603 - prec: 0.7213 - recall: 0.2601 - FN: 87690.0000 - FP: 11914.0000 - TN: 1528445.0000 - TP: 30831.0000 - val_loss: 0.2604 - val_acc: 0.9266 - val_mse: 0.0413 - val_binary_crossentropy: 0.2176 - val_ssim: 0.5929 - val_psnr: 14.0250 - val_cor: 0.3168 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 64/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.1310 - acc: 0.9225 - mse: 0.0225 - binary_crossentropy: 0.0907 - ssim: 0.6682 - psnr: 16.6063 - cor: 0.6675 - prec: 0.7335 - recall: 0.2733 - FN: 86135.0000 - FP: 11767.0000 - TN: 1528592.0000 - TP: 32386.0000 - val_loss: 0.2998 - val_acc: 0.9266 - val_mse: 0.0432 - val_binary_crossentropy: 0.2622 - val_ssim: 0.6638 - val_psnr: 13.8361 - val_cor: 0.2617 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 65/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.1250 - acc: 0.9223 - mse: 0.0219 - binary_crossentropy: 0.0890 - ssim: 0.6814 - psnr: 16.7190 - cor: 0.6767 - prec: 0.7545 - recall: 0.3198 - FN: 80620.0000 - FP: 12334.0000 - TN: 1528025.0000 - TP: 37901.0000 - val_loss: 0.2970 - val_acc: 0.9266 - val_mse: 0.0437 - val_binary_crossentropy: 0.2629 - val_ssim: 0.6398 - val_psnr: 13.7941 - val_cor: 0.2438 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 66/200
# 14/14 [==============================] - 9s 641ms/step - loss: 0.1209 - acc: 0.9222 - mse: 0.0216 - binary_crossentropy: 0.0879 - ssim: 0.6868 - psnr: 16.7842 - cor: 0.6814 - prec: 0.7623 - recall: 0.3353 - FN: 78779.0000 - FP: 12393.0000 - TN: 1527966.0000 - TP: 39742.0000 - val_loss: 0.3066 - val_acc: 0.9266 - val_mse: 0.0439 - val_binary_crossentropy: 0.2748 - val_ssim: 0.6546 - val_psnr: 13.7657 - val_cor: 0.2334 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 67/200
# 14/14 [==============================] - 9s 641ms/step - loss: 0.1181 - acc: 0.9222 - mse: 0.0213 - binary_crossentropy: 0.0869 - ssim: 0.6945 - psnr: 16.8648 - cor: 0.6874 - prec: 0.7652 - recall: 0.3401 - FN: 78212.0000 - FP: 12372.0000 - TN: 1527987.0000 - TP: 40309.0000 - val_loss: 0.3070 - val_acc: 0.9266 - val_mse: 0.0440 - val_binary_crossentropy: 0.2764 - val_ssim: 0.6632 - val_psnr: 13.7552 - val_cor: 0.2606 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 68/200
# 14/14 [==============================] - 9s 640ms/step - loss: 0.1181 - acc: 0.9219 - mse: 0.0216 - binary_crossentropy: 0.0878 - ssim: 0.6931 - psnr: 16.7945 - cor: 0.6839 - prec: 0.7603 - recall: 0.3493 - FN: 77116.0000 - FP: 13052.0000 - TN: 1527307.0000 - TP: 41405.0000 - val_loss: 0.3092 - val_acc: 0.9266 - val_mse: 0.0441 - val_binary_crossentropy: 0.2791 - val_ssim: 0.6580 - val_psnr: 13.7520 - val_cor: 0.2304 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 69/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.1166 - acc: 0.9227 - mse: 0.0211 - binary_crossentropy: 0.0868 - ssim: 0.6984 - psnr: 16.8907 - cor: 0.6911 - prec: 0.7782 - recall: 0.3470 - FN: 77389.0000 - FP: 11723.0000 - TN: 1528636.0000 - TP: 41132.0000 - val_loss: 0.3022 - val_acc: 0.9266 - val_mse: 0.0440 - val_binary_crossentropy: 0.2728 - val_ssim: 0.6556 - val_psnr: 13.7577 - val_cor: 0.2727 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 70/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.1156 - acc: 0.9227 - mse: 0.0210 - binary_crossentropy: 0.0863 - ssim: 0.6997 - psnr: 16.9299 - cor: 0.6955 - prec: 0.7803 - recall: 0.3527 - FN: 76720.0000 - FP: 11769.0000 - TN: 1528590.0000 - TP: 41801.0000 - val_loss: 0.3044 - val_acc: 0.9266 - val_mse: 0.0441 - val_binary_crossentropy: 0.2753 - val_ssim: 0.6564 - val_psnr: 13.7521 - val_cor: 0.2493 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 71/200
# 14/14 [==============================] - 9s 645ms/step - loss: 0.1139 - acc: 0.9218 - mse: 0.0204 - binary_crossentropy: 0.0847 - ssim: 0.7068 - psnr: 17.0285 - cor: 0.7038 - prec: 0.7812 - recall: 0.4091 - FN: 70036.0000 - FP: 13579.0000 - TN: 1526780.0000 - TP: 48485.0000 - val_loss: 0.2926 - val_acc: 0.9266 - val_mse: 0.0438 - val_binary_crossentropy: 0.2632 - val_ssim: 0.6344 - val_psnr: 13.7755 - val_cor: 0.2841 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 72/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.1149 - acc: 0.9229 - mse: 0.0205 - binary_crossentropy: 0.0853 - ssim: 0.7044 - psnr: 17.0120 - cor: 0.7015 - prec: 0.7951 - recall: 0.3728 - FN: 74339.0000 - FP: 11384.0000 - TN: 1528975.0000 - TP: 44182.0000 - val_loss: 0.2721 - val_acc: 0.9266 - val_mse: 0.0432 - val_binary_crossentropy: 0.2423 - val_ssim: 0.6060 - val_psnr: 13.8357 - val_cor: 0.3295 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 73/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.1138 - acc: 0.9227 - mse: 0.0202 - binary_crossentropy: 0.0840 - ssim: 0.7120 - psnr: 17.0794 - cor: 0.7075 - prec: 0.7952 - recall: 0.3916 - FN: 72106.0000 - FP: 11955.0000 - TN: 1528404.0000 - TP: 46415.0000 - val_loss: 0.2648 - val_acc: 0.9266 - val_mse: 0.0427 - val_binary_crossentropy: 0.2351 - val_ssim: 0.6181 - val_psnr: 13.8904 - val_cor: 0.3175 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 74/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.1128 - acc: 0.9224 - mse: 0.0199 - binary_crossentropy: 0.0829 - ssim: 0.7197 - psnr: 17.1662 - cor: 0.7164 - prec: 0.7934 - recall: 0.4056 - FN: 70443.0000 - FP: 12519.0000 - TN: 1527840.0000 - TP: 48078.0000 - val_loss: 0.2725 - val_acc: 0.9266 - val_mse: 0.0429 - val_binary_crossentropy: 0.2426 - val_ssim: 0.6430 - val_psnr: 13.8647 - val_cor: 0.3124 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 75/200
# 14/14 [==============================] - 9s 640ms/step - loss: 0.1108 - acc: 0.9223 - mse: 0.0193 - binary_crossentropy: 0.0812 - ssim: 0.7314 - psnr: 17.2839 - cor: 0.7228 - prec: 0.8032 - recall: 0.4321 - FN: 67312.0000 - FP: 12550.0000 - TN: 1527809.0000 - TP: 51209.0000 - val_loss: 0.2914 - val_acc: 0.9266 - val_mse: 0.0437 - val_binary_crossentropy: 0.2623 - val_ssim: 0.6487 - val_psnr: 13.7894 - val_cor: 0.2808 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 76/200
# 14/14 [==============================] - 9s 640ms/step - loss: 0.1094 - acc: 0.9225 - mse: 0.0191 - binary_crossentropy: 0.0806 - ssim: 0.7313 - psnr: 17.3303 - cor: 0.7253 - prec: 0.8072 - recall: 0.4442 - FN: 65875.0000 - FP: 12573.0000 - TN: 1527786.0000 - TP: 52646.0000 - val_loss: 0.2817 - val_acc: 0.9266 - val_mse: 0.0434 - val_binary_crossentropy: 0.2531 - val_ssim: 0.6372 - val_psnr: 13.8142 - val_cor: 0.2897 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 77/200
# 14/14 [==============================] - 9s 639ms/step - loss: 0.1087 - acc: 0.9226 - mse: 0.0190 - binary_crossentropy: 0.0803 - ssim: 0.7342 - psnr: 17.3570 - cor: 0.7262 - prec: 0.8078 - recall: 0.4355 - FN: 66909.0000 - FP: 12283.0000 - TN: 1528076.0000 - TP: 51612.0000 - val_loss: 0.2783 - val_acc: 0.9266 - val_mse: 0.0432 - val_binary_crossentropy: 0.2501 - val_ssim: 0.6405 - val_psnr: 13.8376 - val_cor: 0.2906 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 78/200
# 14/14 [==============================] - 9s 640ms/step - loss: 0.1084 - acc: 0.9229 - mse: 0.0190 - binary_crossentropy: 0.0803 - ssim: 0.7327 - psnr: 17.3555 - cor: 0.7279 - prec: 0.8122 - recall: 0.4391 - FN: 66478.0000 - FP: 12031.0000 - TN: 1528328.0000 - TP: 52043.0000 - val_loss: 0.2867 - val_acc: 0.9266 - val_mse: 0.0436 - val_binary_crossentropy: 0.2586 - val_ssim: 0.6514 - val_psnr: 13.7972 - val_cor: 0.2972 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 79/200
# 14/14 [==============================] - 9s 641ms/step - loss: 0.1083 - acc: 0.9231 - mse: 0.0190 - binary_crossentropy: 0.0802 - ssim: 0.7395 - psnr: 17.3711 - cor: 0.7314 - prec: 0.8171 - recall: 0.4348 - FN: 66991.0000 - FP: 11537.0000 - TN: 1528822.0000 - TP: 51530.0000 - val_loss: 0.2825 - val_acc: 0.9266 - val_mse: 0.0431 - val_binary_crossentropy: 0.2545 - val_ssim: 0.6696 - val_psnr: 13.8503 - val_cor: 0.3103 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 80/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.1072 - acc: 0.9228 - mse: 0.0186 - binary_crossentropy: 0.0792 - ssim: 0.7393 - psnr: 17.4648 - cor: 0.7338 - prec: 0.8202 - recall: 0.4607 - FN: 63924.0000 - FP: 11968.0000 - TN: 1528391.0000 - TP: 54597.0000 - val_loss: 0.2621 - val_acc: 0.9266 - val_mse: 0.0422 - val_binary_crossentropy: 0.2340 - val_ssim: 0.6469 - val_psnr: 13.9470 - val_cor: 0.3047 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 81/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.1057 - acc: 0.9232 - mse: 0.0181 - binary_crossentropy: 0.0775 - ssim: 0.7511 - psnr: 17.5743 - cor: 0.7432 - prec: 0.8279 - recall: 0.4651 - FN: 63392.0000 - FP: 11460.0000 - TN: 1528899.0000 - TP: 55129.0000 - val_loss: 0.2749 - val_acc: 0.9266 - val_mse: 0.0429 - val_binary_crossentropy: 0.2466 - val_ssim: 0.6493 - val_psnr: 13.8686 - val_cor: 0.2765 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 82/200
# 14/14 [==============================] - 9s 646ms/step - loss: 0.1054 - acc: 0.9234 - mse: 0.0180 - binary_crossentropy: 0.0771 - ssim: 0.7541 - psnr: 17.6108 - cor: 0.7462 - prec: 0.8323 - recall: 0.4638 - FN: 63554.0000 - FP: 11078.0000 - TN: 1529281.0000 - TP: 54967.0000 - val_loss: 0.2787 - val_acc: 0.9266 - val_mse: 0.0427 - val_binary_crossentropy: 0.2506 - val_ssim: 0.6603 - val_psnr: 13.8885 - val_cor: 0.2897 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 83/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.1041 - acc: 0.9231 - mse: 0.0176 - binary_crossentropy: 0.0760 - ssim: 0.7565 - psnr: 17.7119 - cor: 0.7512 - prec: 0.8332 - recall: 0.4993 - FN: 59344.0000 - FP: 11850.0000 - TN: 1528509.0000 - TP: 59177.0000 - val_loss: 0.2893 - val_acc: 0.9266 - val_mse: 0.0435 - val_binary_crossentropy: 0.2613 - val_ssim: 0.6541 - val_psnr: 13.8135 - val_cor: 0.2360 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 84/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.1056 - acc: 0.9232 - mse: 0.0180 - binary_crossentropy: 0.0775 - ssim: 0.7503 - psnr: 17.6145 - cor: 0.7442 - prec: 0.8294 - recall: 0.4735 - FN: 62402.0000 - FP: 11547.0000 - TN: 1528812.0000 - TP: 56119.0000 - val_loss: 0.2520 - val_acc: 0.9266 - val_mse: 0.0420 - val_binary_crossentropy: 0.2238 - val_ssim: 0.6029 - val_psnr: 13.9713 - val_cor: 0.2938 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 85/200
# ...
# Epoch 173/200
# 14/14 [==============================] - 9s 637ms/step - loss: 0.0889 - acc: 0.9266 - mse: 0.0118 - binary_crossentropy: 0.0590 - ssim: 0.8458 - psnr: 19.4440 - cor: 0.8421 - prec: 0.9142 - recall: 0.5980 - FN: 47650.0000 - FP: 6653.0000 - TN: 1533706.0000 - TP: 70871.0000 - val_loss: 0.2936 - val_acc: 0.9266 - val_mse: 0.0428 - val_binary_crossentropy: 0.2639 - val_ssim: 0.6681 - val_psnr: 13.8756 - val_cor: 0.2440 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 174/200
# 14/14 [==============================] - 9s 636ms/step - loss: 0.0886 - acc: 0.9261 - mse: 0.0119 - binary_crossentropy: 0.0590 - ssim: 0.8469 - psnr: 19.4390 - cor: 0.8405 - prec: 0.9069 - recall: 0.6186 - FN: 45201.0000 - FP: 7526.0000 - TN: 1532833.0000 - TP: 73320.0000 - val_loss: 0.3258 - val_acc: 0.9266 - val_mse: 0.0433 - val_binary_crossentropy: 0.2964 - val_ssim: 0.6977 - val_psnr: 13.8278 - val_cor: 0.1872 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 175/200
# 14/14 [==============================] - 9s 639ms/step - loss: 0.0877 - acc: 0.9263 - mse: 0.0117 - binary_crossentropy: 0.0585 - ssim: 0.8488 - psnr: 19.5233 - cor: 0.8430 - prec: 0.9093 - recall: 0.6184 - FN: 45233.0000 - FP: 7309.0000 - TN: 1533050.0000 - TP: 73288.0000 - val_loss: 0.2789 - val_acc: 0.9266 - val_mse: 0.0420 - val_binary_crossentropy: 0.2496 - val_ssim: 0.6565 - val_psnr: 13.9600 - val_cor: 0.2649 - val_prec: 1.0000 - val_recall: 2.2160e-04 - val_FN: 13535.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 3.0000
# Epoch 176/200
# 14/14 [==============================] - 9s 641ms/step - loss: 0.0890 - acc: 0.9264 - mse: 0.0119 - binary_crossentropy: 0.0593 - ssim: 0.8447 - psnr: 19.4292 - cor: 0.8405 - prec: 0.9102 - recall: 0.6010 - FN: 47289.0000 - FP: 7031.0000 - TN: 1533328.0000 - TP: 71232.0000 - val_loss: 0.2772 - val_acc: 0.9257 - val_mse: 0.0410 - val_binary_crossentropy: 0.2471 - val_ssim: 0.6573 - val_psnr: 14.0605 - val_cor: 0.2405 - val_prec: 0.4261 - val_recall: 0.0089 - val_FN: 13417.0000 - val_FP: 163.0000 - val_TN: 170619.0000 - val_TP: 121.0000
# Epoch 177/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.0900 - acc: 0.9262 - mse: 0.0121 - binary_crossentropy: 0.0598 - ssim: 0.8401 - psnr: 19.3561 - cor: 0.8376 - prec: 0.9066 - recall: 0.6060 - FN: 46698.0000 - FP: 7400.0000 - TN: 1532959.0000 - TP: 71823.0000 - val_loss: 0.2757 - val_acc: 0.9264 - val_mse: 0.0412 - val_binary_crossentropy: 0.2455 - val_ssim: 0.6414 - val_psnr: 14.0348 - val_cor: 0.2362 - val_prec: 0.4231 - val_recall: 0.0016 - val_FN: 13516.0000 - val_FP: 30.0000 - val_TN: 170752.0000 - val_TP: 22.0000
# Epoch 178/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.0898 - acc: 0.9261 - mse: 0.0120 - binary_crossentropy: 0.0597 - ssim: 0.8388 - psnr: 19.3972 - cor: 0.8394 - prec: 0.9048 - recall: 0.6078 - FN: 46482.0000 - FP: 7582.0000 - TN: 1532777.0000 - TP: 72039.0000 - val_loss: 0.2584 - val_acc: 0.9248 - val_mse: 0.0408 - val_binary_crossentropy: 0.2285 - val_ssim: 0.6282 - val_psnr: 14.0709 - val_cor: 0.2426 - val_prec: 0.4251 - val_recall: 0.0180 - val_FN: 13294.0000 - val_FP: 330.0000 - val_TN: 170452.0000 - val_TP: 244.0000
# Epoch 179/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.0876 - acc: 0.9265 - mse: 0.0115 - binary_crossentropy: 0.0579 - ssim: 0.8495 - psnr: 19.5554 - cor: 0.8468 - prec: 0.9125 - recall: 0.6169 - FN: 45406.0000 - FP: 7012.0000 - TN: 1533347.0000 - TP: 73115.0000 - val_loss: 0.3010 - val_acc: 0.9265 - val_mse: 0.0422 - val_binary_crossentropy: 0.2716 - val_ssim: 0.6808 - val_psnr: 13.9417 - val_cor: 0.2098 - val_prec: 0.4800 - val_recall: 8.8639e-04 - val_FN: 13526.0000 - val_FP: 13.0000 - val_TN: 170769.0000 - val_TP: 12.0000
# Epoch 180/200
# 14/14 [==============================] - 9s 641ms/step - loss: 0.0864 - acc: 0.9266 - mse: 0.0111 - binary_crossentropy: 0.0569 - ssim: 0.8558 - psnr: 19.7061 - cor: 0.8512 - prec: 0.9165 - recall: 0.6270 - FN: 44211.0000 - FP: 6769.0000 - TN: 1533590.0000 - TP: 74310.0000 - val_loss: 0.2763 - val_acc: 0.9263 - val_mse: 0.0416 - val_binary_crossentropy: 0.2470 - val_ssim: 0.6407 - val_psnr: 13.9884 - val_cor: 0.2154 - val_prec: 0.4952 - val_recall: 0.0038 - val_FN: 13486.0000 - val_FP: 53.0000 - val_TN: 170729.0000 - val_TP: 52.0000
# Epoch 181/200
# 14/14 [==============================] - 9s 641ms/step - loss: 0.0864 - acc: 0.9265 - mse: 0.0112 - binary_crossentropy: 0.0573 - ssim: 0.8499 - psnr: 19.6596 - cor: 0.8485 - prec: 0.9149 - recall: 0.6197 - FN: 45075.0000 - FP: 6834.0000 - TN: 1533525.0000 - TP: 73446.0000 - val_loss: 0.2982 - val_acc: 0.9265 - val_mse: 0.0424 - val_binary_crossentropy: 0.2692 - val_ssim: 0.6687 - val_psnr: 13.9121 - val_cor: 0.2054 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 4.0000 - val_TN: 170778.0000 - val_TP: 0.0000e+00
# Epoch 182/200
# 14/14 [==============================] - 9s 639ms/step - loss: 0.0876 - acc: 0.9266 - mse: 0.0115 - binary_crossentropy: 0.0585 - ssim: 0.8435 - psnr: 19.5722 - cor: 0.8452 - prec: 0.9144 - recall: 0.6075 - FN: 46519.0000 - FP: 6740.0000 - TN: 1533619.0000 - TP: 72002.0000 - val_loss: 0.2784 - val_acc: 0.9264 - val_mse: 0.0418 - val_binary_crossentropy: 0.2492 - val_ssim: 0.6572 - val_psnr: 13.9857 - val_cor: 0.2297 - val_prec: 0.5500 - val_recall: 0.0024 - val_FN: 13505.0000 - val_FP: 27.0000 - val_TN: 170755.0000 - val_TP: 33.0000
# Epoch 183/200
# 14/14 [==============================] - 9s 638ms/step - loss: 0.0881 - acc: 0.9265 - mse: 0.0116 - binary_crossentropy: 0.0587 - ssim: 0.8433 - psnr: 19.5068 - cor: 0.8433 - prec: 0.9119 - recall: 0.6118 - FN: 46014.0000 - FP: 7006.0000 - TN: 1533353.0000 - TP: 72507.0000 - val_loss: 0.2988 - val_acc: 0.9264 - val_mse: 0.0423 - val_binary_crossentropy: 0.2692 - val_ssim: 0.6779 - val_psnr: 13.9270 - val_cor: 0.2082 - val_prec: 0.4407 - val_recall: 0.0019 - val_FN: 13512.0000 - val_FP: 33.0000 - val_TN: 170749.0000 - val_TP: 26.0000
# Epoch 184/200
# 14/14 [==============================] - 9s 639ms/step - loss: 0.0869 - acc: 0.9266 - mse: 0.0113 - binary_crossentropy: 0.0575 - ssim: 0.8517 - psnr: 19.6417 - cor: 0.8486 - prec: 0.9167 - recall: 0.6178 - FN: 45298.0000 - FP: 6654.0000 - TN: 1533705.0000 - TP: 73223.0000 - val_loss: 0.2838 - val_acc: 0.9266 - val_mse: 0.0415 - val_binary_crossentropy: 0.2544 - val_ssim: 0.6635 - val_psnr: 14.0060 - val_cor: 0.2580 - val_prec: 0.0000e+00 - val_recall: 0.0000e+00 - val_FN: 13538.0000 - val_FP: 0.0000e+00 - val_TN: 170782.0000 - val_TP: 0.0000e+00
# Epoch 185/200
# 14/14 [==============================] - 9s 640ms/step - loss: 0.0859 - acc: 0.9267 - mse: 0.0110 - binary_crossentropy: 0.0565 - ssim: 0.8558 - psnr: 19.7716 - cor: 0.8527 - prec: 0.9182 - recall: 0.6204 - FN: 44992.0000 - FP: 6553.0000 - TN: 1533806.0000 - TP: 73529.0000 - val_loss: 0.2912 - val_acc: 0.9262 - val_mse: 0.0416 - val_binary_crossentropy: 0.2617 - val_ssim: 0.6561 - val_psnr: 14.0019 - val_cor: 0.2284 - val_prec: 0.4553 - val_recall: 0.0041 - val_FN: 13482.0000 - val_FP: 67.0000 - val_TN: 170715.0000 - val_TP: 56.0000
# Epoch 186/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.0865 - acc: 0.9267 - mse: 0.0112 - binary_crossentropy: 0.0572 - ssim: 0.8538 - psnr: 19.6959 - cor: 0.8504 - prec: 0.9173 - recall: 0.6147 - FN: 45670.0000 - FP: 6571.0000 - TN: 1533788.0000 - TP: 72851.0000 - val_loss: 0.2721 - val_acc: 0.9265 - val_mse: 0.0411 - val_binary_crossentropy: 0.2430 - val_ssim: 0.6541 - val_psnr: 14.0553 - val_cor: 0.2614 - val_prec: 0.6875 - val_recall: 8.1253e-04 - val_FN: 13527.0000 - val_FP: 5.0000 - val_TN: 170777.0000 - val_TP: 11.0000
# Epoch 187/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.0863 - acc: 0.9268 - mse: 0.0111 - binary_crossentropy: 0.0570 - ssim: 0.8517 - psnr: 19.7374 - cor: 0.8504 - prec: 0.9186 - recall: 0.6203 - FN: 44998.0000 - FP: 6511.0000 - TN: 1533848.0000 - TP: 73523.0000 - val_loss: 0.2783 - val_acc: 0.9265 - val_mse: 0.0415 - val_binary_crossentropy: 0.2489 - val_ssim: 0.6587 - val_psnr: 14.0074 - val_cor: 0.2495 - val_prec: 0.3750 - val_recall: 2.2160e-04 - val_FN: 13535.0000 - val_FP: 5.0000 - val_TN: 170777.0000 - val_TP: 3.0000
# Epoch 188/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.0878 - acc: 0.9264 - mse: 0.0115 - binary_crossentropy: 0.0579 - ssim: 0.8484 - psnr: 19.5853 - cor: 0.8470 - prec: 0.9128 - recall: 0.6193 - FN: 45123.0000 - FP: 7010.0000 - TN: 1533349.0000 - TP: 73398.0000 - val_loss: 0.2812 - val_acc: 0.9258 - val_mse: 0.0415 - val_binary_crossentropy: 0.2509 - val_ssim: 0.6526 - val_psnr: 14.0109 - val_cor: 0.2175 - val_prec: 0.4050 - val_recall: 0.0072 - val_FN: 13440.0000 - val_FP: 144.0000 - val_TN: 170638.0000 - val_TP: 98.0000
# Epoch 189/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.0872 - acc: 0.9269 - mse: 0.0112 - binary_crossentropy: 0.0572 - ssim: 0.8531 - psnr: 19.6963 - cor: 0.8512 - prec: 0.9200 - recall: 0.6137 - FN: 45787.0000 - FP: 6321.0000 - TN: 1534038.0000 - TP: 72734.0000 - val_loss: 0.2835 - val_acc: 0.9264 - val_mse: 0.0415 - val_binary_crossentropy: 0.2541 - val_ssim: 0.6543 - val_psnr: 14.0104 - val_cor: 0.2288 - val_prec: 0.4906 - val_recall: 0.0019 - val_FN: 13512.0000 - val_FP: 27.0000 - val_TN: 170755.0000 - val_TP: 26.0000
# Epoch 190/200
# 14/14 [==============================] - 9s 641ms/step - loss: 0.0865 - acc: 0.9267 - mse: 0.0111 - binary_crossentropy: 0.0572 - ssim: 0.8520 - psnr: 19.7022 - cor: 0.8501 - prec: 0.9178 - recall: 0.6204 - FN: 44990.0000 - FP: 6587.0000 - TN: 1533772.0000 - TP: 73531.0000 - val_loss: 0.2765 - val_acc: 0.9249 - val_mse: 0.0414 - val_binary_crossentropy: 0.2475 - val_ssim: 0.6390 - val_psnr: 14.0182 - val_cor: 0.2253 - val_prec: 0.3918 - val_recall: 0.0148 - val_FN: 13337.0000 - val_FP: 312.0000 - val_TN: 170470.0000 - val_TP: 201.0000
# Epoch 191/200
# 14/14 [==============================] - 9s 638ms/step - loss: 0.0853 - acc: 0.9267 - mse: 0.0109 - binary_crossentropy: 0.0565 - ssim: 0.8561 - psnr: 19.7967 - cor: 0.8531 - prec: 0.9179 - recall: 0.6293 - FN: 43936.0000 - FP: 6669.0000 - TN: 1533690.0000 - TP: 74585.0000 - val_loss: 0.3040 - val_acc: 0.9258 - val_mse: 0.0421 - val_binary_crossentropy: 0.2753 - val_ssim: 0.6771 - val_psnr: 13.9359 - val_cor: 0.2031 - val_prec: 0.3782 - val_recall: 0.0066 - val_FN: 13448.0000 - val_FP: 148.0000 - val_TN: 170634.0000 - val_TP: 90.0000
# Epoch 192/200
# 14/14 [==============================] - 9s 639ms/step - loss: 0.0836 - acc: 0.9271 - mse: 0.0105 - binary_crossentropy: 0.0551 - ssim: 0.8614 - psnr: 19.9760 - cor: 0.8606 - prec: 0.9259 - recall: 0.6268 - FN: 44237.0000 - FP: 5949.0000 - TN: 1534410.0000 - TP: 74284.0000 - val_loss: 0.2709 - val_acc: 0.9255 - val_mse: 0.0411 - val_binary_crossentropy: 0.2425 - val_ssim: 0.6390 - val_psnr: 14.0457 - val_cor: 0.2328 - val_prec: 0.3947 - val_recall: 0.0098 - val_FN: 13405.0000 - val_FP: 204.0000 - val_TN: 170578.0000 - val_TP: 133.0000
# Epoch 193/200
# 14/14 [==============================] - 9s 637ms/step - loss: 0.0815 - acc: 0.9272 - mse: 0.0100 - binary_crossentropy: 0.0534 - ssim: 0.8700 - psnr: 20.1658 - cor: 0.8666 - prec: 0.9266 - recall: 0.6439 - FN: 42201.0000 - FP: 6042.0000 - TN: 1534317.0000 - TP: 76320.0000 - val_loss: 0.2954 - val_acc: 0.9263 - val_mse: 0.0422 - val_binary_crossentropy: 0.2677 - val_ssim: 0.6650 - val_psnr: 13.9422 - val_cor: 0.1937 - val_prec: 0.3438 - val_recall: 0.0016 - val_FN: 13516.0000 - val_FP: 42.0000 - val_TN: 170740.0000 - val_TP: 22.0000
# Epoch 194/200
# 14/14 [==============================] - 9s 640ms/step - loss: 0.0811 - acc: 0.9273 - mse: 0.0101 - binary_crossentropy: 0.0537 - ssim: 0.8733 - psnr: 20.1802 - cor: 0.8683 - prec: 0.9301 - recall: 0.6295 - FN: 43910.0000 - FP: 5607.0000 - TN: 1534752.0000 - TP: 74611.0000 - val_loss: 0.2633 - val_acc: 0.9202 - val_mse: 0.0412 - val_binary_crossentropy: 0.2359 - val_ssim: 0.6329 - val_psnr: 14.0450 - val_cor: 0.2567 - val_prec: 0.4091 - val_recall: 0.0612 - val_FN: 12710.0000 - val_FP: 1196.0000 - val_TN: 169586.0000 - val_TP: 828.0000
# Epoch 195/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.0834 - acc: 0.9273 - mse: 0.0107 - binary_crossentropy: 0.0559 - ssim: 0.8576 - psnr: 19.8709 - cor: 0.8580 - prec: 0.9261 - recall: 0.6096 - FN: 46266.0000 - FP: 5766.0000 - TN: 1534593.0000 - TP: 72255.0000 - val_loss: 0.2699 - val_acc: 0.9216 - val_mse: 0.0422 - val_binary_crossentropy: 0.2423 - val_ssim: 0.6231 - val_psnr: 13.9420 - val_cor: 0.2118 - val_prec: 0.3415 - val_recall: 0.0360 - val_FN: 13050.0000 - val_FP: 941.0000 - val_TN: 169841.0000 - val_TP: 488.0000
# Epoch 196/200
# 14/14 [==============================] - 9s 643ms/step - loss: 0.0834 - acc: 0.9268 - mse: 0.0107 - binary_crossentropy: 0.0555 - ssim: 0.8591 - psnr: 19.8868 - cor: 0.8579 - prec: 0.9208 - recall: 0.6338 - FN: 43400.0000 - FP: 6457.0000 - TN: 1533902.0000 - TP: 75121.0000 - val_loss: 0.2582 - val_acc: 0.9172 - val_mse: 0.0420 - val_binary_crossentropy: 0.2301 - val_ssim: 0.6233 - val_psnr: 13.9595 - val_cor: 0.2602 - val_prec: 0.4166 - val_recall: 0.0940 - val_FN: 12265.0000 - val_FP: 1783.0000 - val_TN: 168999.0000 - val_TP: 1273.0000
# Epoch 197/200
# 14/14 [==============================] - 9s 644ms/step - loss: 0.0842 - acc: 0.9269 - mse: 0.0108 - binary_crossentropy: 0.0559 - ssim: 0.8576 - psnr: 19.8310 - cor: 0.8561 - prec: 0.9219 - recall: 0.6229 - FN: 44693.0000 - FP: 6258.0000 - TN: 1534101.0000 - TP: 73828.0000 - val_loss: 0.2798 - val_acc: 0.9151 - val_mse: 0.0441 - val_binary_crossentropy: 0.2518 - val_ssim: 0.6326 - val_psnr: 13.7585 - val_cor: 0.2271 - val_prec: 0.3730 - val_recall: 0.0946 - val_FN: 12257.0000 - val_FP: 2153.0000 - val_TN: 168629.0000 - val_TP: 1281.0000
# Epoch 198/200
# 14/14 [==============================] - 9s 642ms/step - loss: 0.0850 - acc: 0.9269 - mse: 0.0110 - binary_crossentropy: 0.0569 - ssim: 0.8538 - psnr: 19.7897 - cor: 0.8536 - prec: 0.9214 - recall: 0.6186 - FN: 45202.0000 - FP: 6252.0000 - TN: 1534107.0000 - TP: 73319.0000 - val_loss: 0.2758 - val_acc: 0.9020 - val_mse: 0.0494 - val_binary_crossentropy: 0.2477 - val_ssim: 0.6032 - val_psnr: 13.2569 - val_cor: 0.2538 - val_prec: 0.3623 - val_recall: 0.1940 - val_FN: 10912.0000 - val_FP: 4623.0000 - val_TN: 166159.0000 - val_TP: 2626.0000
# Epoch 199/200
# 14/14 [==============================] - 9s 641ms/step - loss: 0.0845 - acc: 0.9269 - mse: 0.0108 - binary_crossentropy: 0.0559 - ssim: 0.8568 - psnr: 19.8321 - cor: 0.8567 - prec: 0.9215 - recall: 0.6286 - FN: 44021.0000 - FP: 6343.0000 - TN: 1534016.0000 - TP: 74500.0000 - val_loss: 0.2553 - val_acc: 0.9115 - val_mse: 0.0439 - val_binary_crossentropy: 0.2269 - val_ssim: 0.5948 - val_psnr: 13.7538 - val_cor: 0.2532 - val_prec: 0.3771 - val_recall: 0.1270 - val_FN: 11819.0000 - val_FP: 2839.0000 - val_TN: 167943.0000 - val_TP: 1719.0000
# Epoch 200/200
# 14/14 [==============================] - 9s 639ms/step - loss: 0.0835 - acc: 0.9270 - mse: 0.0106 - binary_crossentropy: 0.0554 - ssim: 0.8600 - psnr: 19.9349 - cor: 0.8599 - prec: 0.9228 - recall: 0.6325 - FN: 43552.0000 - FP: 6270.0000 - TN: 1534089.0000 - TP: 74969.0000 - val_loss: 0.2930 - val_acc: 0.9232 - val_mse: 0.0419 - val_binary_crossentropy: 0.2651 - val_ssim: 0.6661 - val_psnr: 13.9771 - val_cor: 0.2131 - val_prec: 0.4278 - val_recall: 0.0357 - val_FN: 13055.0000 - val_FP: 646.0000 - val_TN: 170136.0000 - val_TP: 483.0000

# %%
foldername = "".join(["/content/drive/My Drive/Results_project/Results_MNIST/Results_MCNet/", "loss_BCE_lr_1e-3_ELU_200epochs_BN_BS30_l2_0_001_Inception/"])
# !mkdir "$foldername"

plt.figure(figsize=(12,6))
plt.plot(history.history['loss'][3:], label='Train')
plt.plot(history.history['val_loss'][3:], label='Val')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.xlim(left = 3)
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'loss.png']))
# files.download('loss.png')
#
plt.figure(figsize=(12,6))
plt.plot(history.history['acc'][3:], label='Train')
plt.plot(history.history['val_acc'][3:], label='Val')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.xlim(left = 3)
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'acc.png']))
# files.download('acc.png')

# plt.figure(figsize=(12,6))
# plt.plot(history.history['binary_accuracy'], label='Train')
# plt.plot(history.history['val_binary_accuracy'], label='Val')
# plt.ylabel('binary_accuracy')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'binary_accuracy.png']))
# # files.download('binary_accuracy.png')
# #
# plt.figure(figsize=(12,6))
# plt.plot(history.history['cosine_similarity'], label='Train')
# plt.plot(history.history['val_cosine_similarity'], label='Val')
# plt.ylabel('cosine_similarity')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'cosine_similarity.png']))
# # files.download('cosine_similarity.png')

plt.figure(figsize=(12,6))
plt.plot(history.history['binary_crossentropy'][3:], label='Train')
plt.plot(history.history['val_binary_crossentropy'][3:], label='Val')
plt.ylabel('binary_crossentropy')
plt.xlabel('epoch')
# plt.xlim(left = 3)
# plt.ylim(top = history.history['binary_crossentropy'][3])
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'binary_crossentropy.png']))
# files.download('binary_crossentropy.png')

# plt.figure(figsize=(12,6))
# plt.plot(history.history['logcosh'], label='Train')
# plt.plot(history.history['val_logcosh'], label='Val')
# plt.ylabel('logcosh')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'logcosh.png']))
# # files.download('logcosh.png')

plt.figure(figsize=(12,6))
plt.plot(history.history['mse'][3:], label='Train')
plt.plot(history.history['val_mse'][3:], label='Val')
plt.ylabel('mse')
plt.xlabel('epoch')
# plt.xlim(left = 3)
# plt.ylim(top = history.history['mse'][3])
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'mse.png']))
# files.download('mse.png')

plt.figure(figsize=(12,6))
plt.plot(history.history['prec'][3:], label='Train')
plt.plot(history.history['val_prec'][3:], label='Val')
plt.ylabel('prec')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'prec.png']))
# files.download('prec.png')
#
plt.figure(figsize=(12,6))
plt.plot(history.history['recall'][3:], label='Train')
plt.plot(history.history['val_recall'][3:], label='Val')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'recall.png']))

plt.figure(figsize=(12,6))
plt.plot(history.history['ssim'][3:], label='Train')
plt.plot(history.history['val_ssim'][3:], label='Val')
plt.ylabel('ssim')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'ssim.png']))
# files.download('ssim.png')
#
plt.figure(figsize=(12,6))
plt.plot(history.history['psnr'][3:], label='Train')
plt.plot(history.history['val_psnr'][3:], label='Val')
plt.ylabel('psnr')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'psnr.png']))
# files.download('psnr.png')
#
plt.figure(figsize=(12,6))
plt.plot(history.history['cor'][3:], label='Train')
plt.plot(history.history['val_cor'][3:], label='Val')
plt.ylabel('cor')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'cor.png']))
# files.download('cor.png')

plt.figure(figsize=(12,6))
plt.plot(history.history['FN'][3:], label='Train')
plt.plot(history.history['val_FN'][3:], label='Val')
plt.ylabel('FN')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'FN.png']))
# files.download('FN.png')
#
plt.figure(figsize=(12,6))
plt.plot(history.history['FP'][3:], label='Train')
plt.plot(history.history['val_FP'][3:], label='Val')
plt.ylabel('FP')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'FP.png']))
# files.download('FP.png')
#
plt.figure(figsize=(12,6))
plt.plot(history.history['TN'][3:], label='Train')
plt.plot(history.history['val_TN'][3:], label='Val')
plt.ylabel('TN')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'TN.png']))
# files.download('TN.png')
#
plt.figure(figsize=(12,6))
plt.plot(history.history['TP'][3:], label='Train')
plt.plot(history.history['val_TP'][3:], label='Val')
plt.ylabel('TP')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'TP.png']))
# files.download('TP.png')

# %%
# Select a random observation, initial trajectory and predicted trajectory
itest = 50
init_traj = 10
pred_traj = data.shape[1] - init_traj
track_MCNet_motion = X_MCNet_motion[itest, :, :, :, :]
track_MCNet_content = X_MCNet_content[itest, :, :, :]
track = data[itest, :init_traj, :, :, :]
print(track.shape)
print(track_MCNet_content.shape)
print(track_MCNet_motion.shape)
# for i in range(pred_traj):
for i in range(10):
  new_pos = model.predict([track_MCNet_motion[None, :, :, :, :], track_MCNet_content[None, :,:,:]])
  print(new_pos.shape)
  track = np.concatenate((track, new_pos), axis=0)
  track_MCNet_content = new_pos[0]
  track_MCNet_motion = np.concatenate((track_MCNet_motion, new_pos), axis=0)
  track_MCNet_motion[-1] = track_MCNet_motion[-1] - track_MCNet_motion[-2]
print("track:", track.shape)
# Out:
# (10, 64, 64, 1)
# (64, 64, 1)
# (9, 64, 64, 1)
# (1, 64, 64, 1)
# (1, 64, 64, 1)
# (1, 64, 64, 1)
# (1, 64, 64, 1)
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efa05ec6950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# (1, 64, 64, 1)
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efa05ec6950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# (1, 64, 64, 1)
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efa05ec6950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# (1, 64, 64, 1)
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efa05ec6950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# (1, 64, 64, 1)
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efa05ec6950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# (1, 64, 64, 1)
# WARNING:tensorflow:10 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efa05ec6950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# (1, 64, 64, 1)
# track: (20, 64, 64, 1)

# %%
# Plot results
true_track = data[itest, :, :, :, 0]

for i in range(20):
    plt.figure(figsize=(10, 5))

    plt.subplot(121)
    if i >= init_traj:
        plt.text(1, 3, 'Prediction', color='w')
    else:
        plt.text(1, 3, 'Initial trajectory', color='w')
    plt.imshow(track[i, :, :, 0])

    plt.subplot(122)
    plt.text(1, 3, 'Ground truth', color='w')
    plt.imshow(true_track[i, :, :])

    plt.savefig('anim_%i.png' % (i+1))
    #files.download('anim_%i.png' % (i+1))
