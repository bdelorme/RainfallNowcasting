# %%
# mounts Google Drive to the Colab VM
from google.colab import drive, files
drive.mount('/content/drive', force_remount=True)

# project github foldername
FOLDERNAME = '/content/drive/My Drive/CS231N/Project/RainfallNowcasting/MovingMNIST/'

# load python files from foldername
import sys
sys.path.append(FOLDERNAME)

# for auto-reloading external modules
# %load_ext autoreload
# %autoreload 2
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Download Moving-MNIST dataset
# !wget 'http://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy'
# Out:
# --2020-05-17 20:25:47--  http://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 819200096 (781M)
# Saving to: ‘mnist_test_seq.npy’
#
# mnist_test_seq.npy  100%[===================>] 781.25M  49.6MB/s    in 18s
#
# 2020-05-17 20:26:05 (43.7 MB/s) - ‘mnist_test_seq.npy’ saved [819200096/819200096]

# %%
# Useful libraries
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 3
np.set_printoptions(precision=2)

# %%
# Data processing
data = np.load('mnist_test_seq.npy')
data = data.swapaxes(0, 1) # swap frames and instances for tf handling
data = data[:500, :, :, :] # reduce memory and compute requirements by selecting a subsample
data = np.expand_dims(data, -1) # add channel dimension for tf handling (channel=1, ie grayscale)
train_data = data[:450, :, :, :]
val_data = data[450:, :, :, :]
train_data = train_data/np.max(data)
val_data = val_data/np.max(data)
# mean = np.mean(train_data)
# train_data = train_data - mean
# val_data = val_data - mean
# data = data - np.max(data) + np.min # normalize between 0 and 1 (min-max scaling)
# data = (data - 0.5)*2
N, F, H, W, C = data.shape # dims
print('dataset = '+str(data.shape)) # shape is [instance x frame x height x width x channel]
# Out:
# dataset = (500, 20, 64, 64, 1)

# %%
print(np.max(data))
print(np.min(data))
# Out:
# 255
# 0

# %%
def MCNet_data(data, cutoff):
  X = data[:, :cutoff, :, :, :]
  y_MCNet = data[:, cutoff, :, :, :]
  X_MCNet_content = X[:, -1, :, :, :]
  X_MCNet_motion = X[:, 1:, :, :, :] - X[:, :-1, :, :, :]
  #X_MCNet_motion = X[:, :-1, :, :, :]
  return X_MCNet_motion, X_MCNet_content, y_MCNet
init_traj = 10
X_MCNet_motion, X_MCNet_content, y_MCNet = MCNet_data(train_data, init_traj)
X_val_MCNet_motion, X_val_MCNet_content, y_val_MCNet = MCNet_data(val_data, init_traj)
print("X_MCNet_motion is:", X_MCNet_motion.shape)
print("X_MCNet_content is:", X_MCNet_content.shape)
print("y_MCNet is:", y_MCNet.shape)
X_MCNet_motion = tf.cast(X_MCNet_motion, tf.float32)
X_MCNet_content = tf.cast(X_MCNet_content, tf.float32)
y_MCNet = tf.cast(y_MCNet, tf.float32)
X_val_MCNet_motion = tf.cast(X_val_MCNet_motion, tf.float32)
X_val_MCNet_content = tf.cast(X_val_MCNet_content, tf.float32)
y_val_MCNet = tf.cast(y_val_MCNet, tf.float32)
# Out:
# X_MCNet_motion is: (450, 9, 64, 64, 1)
# X_MCNet_content is: (450, 64, 64, 1)
# y_MCNet is: (450, 64, 64, 1)

# %%
# Our Model Architecture
def model_init():
    inputs_motion = tf.keras.Input(shape=[None, H, W, C])
    inputs_content = tf.keras.Input(shape=[H, W, C])

    inputs_by2 = tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same')(inputs_content)
    inputs_by4 = tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same')(inputs_by2)
    inputs_by8 = tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same')(inputs_by4)

    # Motion Encoder
    # Layer 1
    tcnv1 = tf.keras.layers.TimeDistributed(tf.keras.layers.Conv2D(64, (5,5), activation='relu', padding='same', kernel_initializer='he_normal'))(inputs_motion) 
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.MaxPooling2D((2,2)))(tcnv1) #original (2,2)
    # Layer 2
    tcnv2 = tf.keras.layers.TimeDistributed(tf.keras.layers.Conv2D(64, (5,5), activation='relu', padding='same', kernel_initializer='he_normal'))(x)
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.MaxPooling2D((2,2)))(tcnv2)
    # Layer 3
    tcnv3 = tf.keras.layers.TimeDistributed(tf.keras.layers.Conv2D(64, (7,7), activation='relu', padding='same', kernel_initializer='he_normal'))(x)
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.MaxPooling2D((2,2)))(tcnv3)
    # Layer 4
    ME = tf.keras.layers.ConvLSTM2D(512, (7,7), activation='relu', padding='same', return_sequences=False, kernel_initializer='he_normal', dropout=0.8, recurrent_dropout=0.8)(x)           
    
    # Content Encoder
    
    x = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(inputs_content)
    x = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)    
    x = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(x)
    x = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x) 
    x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(x)
    x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    CE = tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x) 

    # Residuals 
    res3 = tf.keras.layers.Lambda(lambda x: x[:,-1])(tcnv3)
    res2 = tf.keras.layers.Lambda(lambda x: x[:,-1])(tcnv2)
    res1 = tf.keras.layers.Lambda(lambda x: x[:,-1])(tcnv1)


    l2_001 = tf.keras.optimizers
    # Combination layers
    concat = tf.keras.layers.Concatenate()([CE, ME])
    x = tf.keras.layers.Conv2D(256, 5, activation='relu', padding='same', kernel_initializer='he_normal')(concat)
    x = tf.keras.layers.Conv2D(128, 5, activation='relu', padding='same', kernel_initializer='he_normal')(x)
    combined = tf.keras.layers.Conv2D(256, 5, activation='relu', padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)

    # Decoder layers
    x = tf.keras.layers.UpSampling2D((2,2))(combined)
    x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(x)
    x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(x) #new
    x = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(x) #new
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.Concatenate()([x, res3]) #res3
    x = tf.keras.layers.UpSampling2D((2,2), name='decoder_upsample_2')(x)
    x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(x)
    x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(x) #new
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.Concatenate()([x, res2])
    x = tf.keras.layers.UpSampling2D((2,2), name='decoder_upsample_3')(x)
    x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(x)
    x = tf.keras.layers.Concatenate()([x, res1]) #res1
    

    # Prediction
    preds = tf.keras.layers.Conv2D(1, 1, activation='sigmoid', padding='same')(x) #sigmoid original
    return tf.keras.Model(inputs=[inputs_motion, inputs_content], outputs=preds)

# %%
# Custom metrics: SSIM, PSNR, POD, FAR

def ssim(y_gt, y_pred, max_val=1.):
  return tf.image.ssim(y_gt, y_pred, max_val)

def psnr(y_gt, y_pred, max_val=1.):
  return tf.image.psnr(y_gt, y_pred, max_val)

def cor(y_gt, y_pred):
  return tfp.stats.correlation(y_gt, y_pred, sample_axis=None, event_axis=None)

# %%
# Custom Loss
def mse_modified(y_gt, y_pred, max_val=.1):
  # y_gt_pred_eq = tf.math.equal(y_gt, y_pred)
  y_gt_0 = tf.math.count_nonzero(tf.math.equal(y_gt, 0), dtype=tf.dtypes.float32)
  # y_both_0 = tf.math.logical_and(y_gt_pred_eq, y_pred_0)
  # num_both_0 = tf.math.count_nonzero(y_both_0, dtype=tf.dtypes.float32)
  size_y = tf.size(y_gt, out_type=tf.dtypes.float32)
  return tf.keras.losses.MSE(y_gt, y_pred)*size_y/(size_y - y_gt_0 + 1)**2


def ssim_loss(y_gt, y_pred, max_val=1.):
  return 1-tf.math.reduce_mean(tf.image.ssim(y_gt, y_pred, max_val))

def mse_mae_ssim_loss(y_gt, y_pred, max_val=1.):
  return ssim_loss(y_gt, y_pred, max_val) + \
         tf.keras.losses.MSE(y_gt, y_pred) + \
         tf.keras.losses.MAE(y_gt, y_pred)

def mse_binary_crossentropy(y_gt, y_pred, max_val=1.):
  return tf.keras.losses.MSE(y_gt, y_pred) + tf.keras.losses.binary_crossentropy(y_gt, y_pred)

# %%
fl = tfa.losses.SigmoidFocalCrossEntropy()
model = model_init()
# Build optimizer
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-3),
              loss=fl,
              metrics=['acc', 'mse', 'binary_crossentropy'])
# metrics=['acc', 'mse', 'mae', 'binary_accuracy','cosine_similarity', 'logcosh', 'binary_crossentropy', 
#                        ssim, psnr, cor, mse_modified]
# Fit the model
history = model.fit([X_MCNet_motion, X_MCNet_content], y_MCNet, batch_size=30, epochs=50, validation_data=([X_val_MCNet_motion, X_val_MCNet_content], y_val_MCNet))
model[loss] = model
# Out:
# Epoch 1/50
# 15/15 [==============================] - 44s 3s/step - loss: 0.1858 - acc: 0.8481 - mse: 0.0904 - binary_crossentropy: 0.8217 - val_loss: 0.1591 - val_acc: 0.9319 - val_mse: 0.0407 - val_binary_crossentropy: 53.1924
# Epoch 2/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0564 - acc: 0.9168 - mse: 0.0390 - binary_crossentropy: 0.3156 - val_loss: 0.1590 - val_acc: 0.9317 - val_mse: 0.0409 - val_binary_crossentropy: 3.5646
# Epoch 3/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0109 - acc: 0.9267 - mse: 0.0274 - binary_crossentropy: 0.1189 - val_loss: 0.0261 - val_acc: 0.9267 - val_mse: 0.0315 - val_binary_crossentropy: 0.1506
# Epoch 4/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0101 - acc: 0.9270 - mse: 0.0256 - binary_crossentropy: 0.1122 - val_loss: 0.0175 - val_acc: 0.9234 - val_mse: 0.0294 - val_binary_crossentropy: 0.1192
# Epoch 5/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0099 - acc: 0.9273 - mse: 0.0251 - binary_crossentropy: 0.1098 - val_loss: 0.0257 - val_acc: 0.8987 - val_mse: 0.0355 - val_binary_crossentropy: 0.1339
# Epoch 6/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0100 - acc: 0.9268 - mse: 0.0251 - binary_crossentropy: 0.1096 - val_loss: 0.0113 - val_acc: 0.9268 - val_mse: 0.0253 - val_binary_crossentropy: 0.1091
# Epoch 7/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0097 - acc: 0.9275 - mse: 0.0246 - binary_crossentropy: 0.1074 - val_loss: 0.0140 - val_acc: 0.9149 - val_mse: 0.0283 - val_binary_crossentropy: 0.1182
# Epoch 8/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0098 - acc: 0.9271 - mse: 0.0246 - binary_crossentropy: 0.1079 - val_loss: 0.0106 - val_acc: 0.9255 - val_mse: 0.0253 - val_binary_crossentropy: 0.1105
# Epoch 9/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0095 - acc: 0.9275 - mse: 0.0243 - binary_crossentropy: 0.1064 - val_loss: 0.0097 - val_acc: 0.9301 - val_mse: 0.0247 - val_binary_crossentropy: 0.1077
# Epoch 10/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0095 - acc: 0.9276 - mse: 0.0240 - binary_crossentropy: 0.1055 - val_loss: 0.0117 - val_acc: 0.9224 - val_mse: 0.0273 - val_binary_crossentropy: 0.1161
# Epoch 11/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0100 - acc: 0.9267 - mse: 0.0246 - binary_crossentropy: 0.1064 - val_loss: 0.0120 - val_acc: 0.9209 - val_mse: 0.0274 - val_binary_crossentropy: 0.1158
# Epoch 12/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0102 - acc: 0.9262 - mse: 0.0247 - binary_crossentropy: 0.1066 - val_loss: 0.0118 - val_acc: 0.9214 - val_mse: 0.0272 - val_binary_crossentropy: 0.1145
# Epoch 13/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0102 - acc: 0.9262 - mse: 0.0247 - binary_crossentropy: 0.1066 - val_loss: 0.0094 - val_acc: 0.9322 - val_mse: 0.0244 - val_binary_crossentropy: 0.1040
# Epoch 14/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0096 - acc: 0.9274 - mse: 0.0240 - binary_crossentropy: 0.1045 - val_loss: 0.0091 - val_acc: 0.9312 - val_mse: 0.0244 - val_binary_crossentropy: 0.1060
# Epoch 15/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0093 - acc: 0.9277 - mse: 0.0237 - binary_crossentropy: 0.1040 - val_loss: 0.0099 - val_acc: 0.9286 - val_mse: 0.0254 - val_binary_crossentropy: 0.1097
# Epoch 16/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0095 - acc: 0.9274 - mse: 0.0240 - binary_crossentropy: 0.1047 - val_loss: 0.0093 - val_acc: 0.9304 - val_mse: 0.0245 - val_binary_crossentropy: 0.1059
# Epoch 17/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0094 - acc: 0.9274 - mse: 0.0238 - binary_crossentropy: 0.1047 - val_loss: 0.0090 - val_acc: 0.9322 - val_mse: 0.0240 - val_binary_crossentropy: 0.1025
# Epoch 18/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0094 - acc: 0.9276 - mse: 0.0237 - binary_crossentropy: 0.1038 - val_loss: 0.0109 - val_acc: 0.9247 - val_mse: 0.0263 - val_binary_crossentropy: 0.1114
# Epoch 19/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0099 - acc: 0.9265 - mse: 0.0244 - binary_crossentropy: 0.1056 - val_loss: 0.0091 - val_acc: 0.9322 - val_mse: 0.0238 - val_binary_crossentropy: 0.1011
# Epoch 20/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0097 - acc: 0.9271 - mse: 0.0240 - binary_crossentropy: 0.1042 - val_loss: 0.0088 - val_acc: 0.9318 - val_mse: 0.0234 - val_binary_crossentropy: 0.1010
# Epoch 21/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0093 - acc: 0.9276 - mse: 0.0236 - binary_crossentropy: 0.1033 - val_loss: 0.0090 - val_acc: 0.9309 - val_mse: 0.0239 - val_binary_crossentropy: 0.1033
# Epoch 22/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0092 - acc: 0.9277 - mse: 0.0235 - binary_crossentropy: 0.1032 - val_loss: 0.0091 - val_acc: 0.9306 - val_mse: 0.0240 - val_binary_crossentropy: 0.1035
# Epoch 23/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0093 - acc: 0.9276 - mse: 0.0235 - binary_crossentropy: 0.1029 - val_loss: 0.0090 - val_acc: 0.9309 - val_mse: 0.0236 - val_binary_crossentropy: 0.1020
# Epoch 24/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0095 - acc: 0.9272 - mse: 0.0239 - binary_crossentropy: 0.1040 - val_loss: 0.0097 - val_acc: 0.9290 - val_mse: 0.0249 - val_binary_crossentropy: 0.1065
# Epoch 25/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0095 - acc: 0.9270 - mse: 0.0238 - binary_crossentropy: 0.1033 - val_loss: 0.0088 - val_acc: 0.9318 - val_mse: 0.0234 - val_binary_crossentropy: 0.1013
# Epoch 26/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0093 - acc: 0.9275 - mse: 0.0235 - binary_crossentropy: 0.1030 - val_loss: 0.0089 - val_acc: 0.9316 - val_mse: 0.0236 - val_binary_crossentropy: 0.1016
# Epoch 27/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0092 - acc: 0.9278 - mse: 0.0233 - binary_crossentropy: 0.1027 - val_loss: 0.0088 - val_acc: 0.9321 - val_mse: 0.0233 - val_binary_crossentropy: 0.1000
# Epoch 28/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0091 - acc: 0.9277 - mse: 0.0232 - binary_crossentropy: 0.1021 - val_loss: 0.0091 - val_acc: 0.9322 - val_mse: 0.0237 - val_binary_crossentropy: 0.0997
# Epoch 29/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0097 - acc: 0.9268 - mse: 0.0239 - binary_crossentropy: 0.1034 - val_loss: 0.0103 - val_acc: 0.9321 - val_mse: 0.0245 - val_binary_crossentropy: 0.0992
# Epoch 30/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0096 - acc: 0.9271 - mse: 0.0238 - binary_crossentropy: 0.1033 - val_loss: 0.0093 - val_acc: 0.9322 - val_mse: 0.0236 - val_binary_crossentropy: 0.0980
# Epoch 31/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0092 - acc: 0.9276 - mse: 0.0234 - binary_crossentropy: 0.1019 - val_loss: 0.0088 - val_acc: 0.9322 - val_mse: 0.0230 - val_binary_crossentropy: 0.0975
# Epoch 32/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0091 - acc: 0.9278 - mse: 0.0232 - binary_crossentropy: 0.1017

# %%
model_memory = model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
              loss='mse',
              metrics=['acc', 'mse', 'binary_crossentropy'])
# metrics=['acc', 'mse', 'mae', 'binary_accuracy','cosine_similarity', 'logcosh', 'binary_crossentropy', 
#                        ssim, psnr, cor, mse_modified]
# Fit the model
history = model.fit([X_MCNet_motion, X_MCNet_content], y_MCNet, batch_size=30, epochs=50, validation_data=([X_val_MCNet_motion, X_val_MCNet_content], y_val_MCNet))
# Out:
# Epoch 1/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0220 - acc: 0.9264 - mse: 0.0220 - binary_crossentropy: 0.0934 - val_loss: 0.0218 - val_acc: 0.9309 - val_mse: 0.0218 - val_binary_crossentropy: 0.0911
# Epoch 2/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0218 - acc: 0.9258 - mse: 0.0218 - binary_crossentropy: 0.0920 - val_loss: 0.0217 - val_acc: 0.9302 - val_mse: 0.0217 - val_binary_crossentropy: 0.0905
# Epoch 3/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0216 - acc: 0.9257 - mse: 0.0216 - binary_crossentropy: 0.0915 - val_loss: 0.0216 - val_acc: 0.9303 - val_mse: 0.0216 - val_binary_crossentropy: 0.0898
# Epoch 4/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0215 - acc: 0.9249 - mse: 0.0215 - binary_crossentropy: 0.0907 - val_loss: 0.0215 - val_acc: 0.9299 - val_mse: 0.0215 - val_binary_crossentropy: 0.0895
# Epoch 5/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0214 - acc: 0.9251 - mse: 0.0214 - binary_crossentropy: 0.0903 - val_loss: 0.0214 - val_acc: 0.9295 - val_mse: 0.0214 - val_binary_crossentropy: 0.0891
# Epoch 6/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0213 - acc: 0.9244 - mse: 0.0213 - binary_crossentropy: 0.0901 - val_loss: 0.0214 - val_acc: 0.9297 - val_mse: 0.0214 - val_binary_crossentropy: 0.0888
# Epoch 7/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0212 - acc: 0.9248 - mse: 0.0212 - binary_crossentropy: 0.0896 - val_loss: 0.0213 - val_acc: 0.9291 - val_mse: 0.0213 - val_binary_crossentropy: 0.0887
# Epoch 8/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0212 - acc: 0.9242 - mse: 0.0212 - binary_crossentropy: 0.0894 - val_loss: 0.0213 - val_acc: 0.9293 - val_mse: 0.0213 - val_binary_crossentropy: 0.0885
# Epoch 9/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0211 - acc: 0.9244 - mse: 0.0211 - binary_crossentropy: 0.0890 - val_loss: 0.0213 - val_acc: 0.9292 - val_mse: 0.0213 - val_binary_crossentropy: 0.0883
# Epoch 10/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0210 - acc: 0.9243 - mse: 0.0210 - binary_crossentropy: 0.0887 - val_loss: 0.0212 - val_acc: 0.9290 - val_mse: 0.0212 - val_binary_crossentropy: 0.0881
# Epoch 11/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0210 - acc: 0.9240 - mse: 0.0210 - binary_crossentropy: 0.0888 - val_loss: 0.0212 - val_acc: 0.9293 - val_mse: 0.0212 - val_binary_crossentropy: 0.0880
# Epoch 12/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0210 - acc: 0.9245 - mse: 0.0210 - binary_crossentropy: 0.0884 - val_loss: 0.0212 - val_acc: 0.9286 - val_mse: 0.0212 - val_binary_crossentropy: 0.0880
# Epoch 13/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0209 - acc: 0.9238 - mse: 0.0209 - binary_crossentropy: 0.0886 - val_loss: 0.0212 - val_acc: 0.9295 - val_mse: 0.0212 - val_binary_crossentropy: 0.0878
# Epoch 14/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0209 - acc: 0.9243 - mse: 0.0209 - binary_crossentropy: 0.0883 - val_loss: 0.0212 - val_acc: 0.9286 - val_mse: 0.0212 - val_binary_crossentropy: 0.0877
# Epoch 15/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0209 - acc: 0.9238 - mse: 0.0209 - binary_crossentropy: 0.0879 - val_loss: 0.0212 - val_acc: 0.9292 - val_mse: 0.0212 - val_binary_crossentropy: 0.0876
# Epoch 16/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0208 - acc: 0.9239 - mse: 0.0208 - binary_crossentropy: 0.0879 - val_loss: 0.0211 - val_acc: 0.9290 - val_mse: 0.0211 - val_binary_crossentropy: 0.0875
# Epoch 17/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0208 - acc: 0.9240 - mse: 0.0208 - binary_crossentropy: 0.0878 - val_loss: 0.0211 - val_acc: 0.9290 - val_mse: 0.0211 - val_binary_crossentropy: 0.0874
# Epoch 18/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0208 - acc: 0.9238 - mse: 0.0208 - binary_crossentropy: 0.0879 - val_loss: 0.0211 - val_acc: 0.9293 - val_mse: 0.0211 - val_binary_crossentropy: 0.0873
# Epoch 19/50
# 15/15 [==============================] - 41s 3s/step - loss: 0.0208 - acc: 0.9240 - mse: 0.0208 - binary_crossentropy: 0.0876 - val_loss: 0.0211 - val_acc: 0.9288 - val_mse: 0.0211 - val_binary_crossentropy: 0.0872
# Epoch 20/50
# 14/15 [===========================>..] - ETA: 2s - loss: 0.0207 - acc: 0.9237 - mse: 0.0207 - binary_crossentropy: 0.0873
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-a529edb42751> in <module>()
#       5 #                        ssim, psnr, cor, mse_modified]
#       6 # Fit the model
# ----> 7 history = model.fit([X_MCNet_motion, X_MCNet_content], y_MCNet, batch_size=30, epochs=50, validation_data=([X_val_MCNet_motion, X_val_MCNet_content], y_val_MCNet))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
foldername = "".join(["/content/drive/My Drive/Results_project/Results_MNIST/Results_MCNet/", "loss_FocalCrossentropy_then_MSE_BatchNorm/"])
# !mkdir "$foldername"

plt.figure(figsize=(12,6))
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'loss.png']))
# files.download('loss.png')
#
plt.figure(figsize=(12,6))
plt.plot(history.history['acc'], label='Train')
plt.plot(history.history['val_acc'], label='Val')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'acc.png']))
# files.download('acc.png')

# plt.figure(figsize=(12,6))
# plt.plot(history.history['binary_accuracy'], label='Train')
# plt.plot(history.history['val_binary_accuracy'], label='Val')
# plt.ylabel('binary_accuracy')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'binary_accuracy.png']))
# # files.download('binary_accuracy.png')
# #
plt.figure(figsize=(12,6))
plt.plot(history.history['cosine_similarity'], label='Train')
plt.plot(history.history['val_cosine_similarity'], label='Val')
plt.ylabel('cosine_similarity')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'cosine_similarity.png']))
# files.download('cosine_similarity.png')

plt.figure(figsize=(12,6))
plt.plot(history.history['binary_crossentropy'], label='Train')
plt.plot(history.history['val_binary_crossentropy'], label='Val')
plt.ylabel('binary_crossentropy')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'binary_crossentropy.png']))
# files.download('binary_crossentropy.png')

# plt.figure(figsize=(12,6))
# plt.plot(history.history['logcosh'], label='Train')
# plt.plot(history.history['val_logcosh'], label='Val')
# plt.ylabel('logcosh')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'logcosh.png']))
# # files.download('logcosh.png')

plt.figure(figsize=(12,6))
plt.plot(history.history['mse'], label='Train')
plt.plot(history.history['val_mse'], label='Val')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'mse.png']))
# files.download('mse.png')
#
# plt.figure(figsize=(12,6))
# plt.plot(history.history['mae'], label='Train')
# plt.plot(history.history['val_mae'], label='Val')
# plt.ylabel('mae')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'mae.png']))
# # files.download('mae.png')
# #
# plt.figure(figsize=(12,6))
# plt.plot(history.history['prec'], label='Train')
# plt.plot(history.history['val_prec'], label='Val')
# plt.ylabel('prec')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'prec.png']))
# # files.download('prec.png')
# #
# plt.figure(figsize=(12,6))
# plt.plot(history.history['recall'], label='Train')
# plt.plot(history.history['val_recall'], label='Val')
# plt.ylabel('recall')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'recall.png']))
# files.download('recall.png')
#
# plt.figure(figsize=(12,6))
# plt.plot(history.history['ssim'], label='Train')
# plt.plot(history.history['val_ssim'], label='Val')
# plt.ylabel('ssim')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'ssim.png']))
# # files.download('ssim.png')
# #
# plt.figure(figsize=(12,6))
# plt.plot(history.history['psnr'], label='Train')
# plt.plot(history.history['val_psnr'], label='Val')
# plt.ylabel('psnr')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'psnr.png']))
# # files.download('psnr.png')
# #
# plt.figure(figsize=(12,6))
# plt.plot(history.history['cor'], label='Train')
# plt.plot(history.history['val_cor'], label='Val')
# plt.ylabel('cor')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'cor.png']))
# # files.download('cor.png')

# plt.figure(figsize=(12,6))
# plt.plot(history.history['FN'], label='Train')
# plt.plot(history.history['val_FN'], label='Val')
# plt.ylabel('FN')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'FN.png']))
# # files.download('FN.png')
# #
# plt.figure(figsize=(12,6))
# plt.plot(history.history['FP'], label='Train')
# plt.plot(history.history['val_FP'], label='Val')
# plt.ylabel('FP')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'FP.png']))
# # files.download('FP.png')
# #
# plt.figure(figsize=(12,6))
# plt.plot(history.history['TN'], label='Train')
# plt.plot(history.history['val_TN'], label='Val')
# plt.ylabel('TN')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'TN.png']))
# # files.download('TN.png')
# #
# plt.figure(figsize=(12,6))
# plt.plot(history.history['TP'], label='Train')
# plt.plot(history.history['val_TP'], label='Val')
# plt.ylabel('TP')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'TP.png']))
# # files.download('TP.png')

# plt.figure(figsize=(12,6))
# plt.plot(history.history['mse_modified'], label='Train')
# plt.plot(history.history['val_mse_modified'], label='Val')
# plt.ylabel('mse_modified')
# plt.xlabel('epoch')
# plt.legend(loc='upper left')
# plt.savefig("".join([foldername,'mse_modified.png']))
# # files.download('TP.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-9b14c4604e47> in <module>()
#       3
#       4 plt.figure(figsize=(12,6))
# ----> 5 plt.plot(history.history['loss'], label='Train')
#       6 plt.plot(history.history['val_loss'], label='Val')
#       7 plt.ylabel('loss')
#
# NameError: name 'history' is not defined

# %%
fl = tfa.losses.SigmoidFocalCrossEntropy()
res = {}
best_model = None
best_valacc = 0

model = model_init()
# Build optimizer
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2),
              loss=fl,
              metrics=['acc', 'mse','binary_crossentropy'])
# Fit the model
history = model.fit([X_MCNet_motion, X_MCNet_content], y_MCNet, batch_size=10, epochs=10, validation_split=0.1)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
              loss='mse',
              metrics=['acc', 'mse','binary_crossentropy'])
# Fit the model
history = model.fit([X_MCNet_motion, X_MCNet_content], y_MCNet, batch_size=10, epochs=10, validation_split=0.1)

foldername = "".join(["/content/drive/My Drive/Results_project/Results_MNIST/Results_MCNet/", "loss_10epoch_fl_10_mse/"])
# !mkdir "$foldername"

plt.figure(figsize=(12,6))
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'loss.png']))

plt.figure(figsize=(12,6))
plt.plot(history.history['acc'], label='Train')
plt.plot(history.history['val_acc'], label='Val')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'acc.png']))
  
plt.figure(figsize=(12,6))
plt.plot(history.history['binary_crossentropy'], label='Train')
plt.plot(history.history['val_binary_crossentropy'], label='Val')
plt.ylabel('binary_crossentropy')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'binary_crossentropy.png']))
  
plt.figure(figsize=(12,6))
plt.plot(history.history['mse'], label='Train')
plt.plot(history.history['val_mse'], label='Val')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.savefig("".join([foldername,'mse.png']))
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-68-bfa53636d377> in <module>()
#      10               metrics=['acc', 'mse','binary_crossentropy'])
#      11 # Fit the model
# ---> 12 history = model.fit([X_MCNet_motion, X_MCNet_content], y_MCNet, batch_size=10, epochs=10, validation_split=0.1)
#      13
#      14 model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     642         # Lifting succeeded, so variables are initialized and we can run the
#     643         # stateless function.
# --> 644         return self._stateless_fn(*args, **kwds)
#     645     else:
#     646       canon_args, canon_kwds = \
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[7,7,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model_15/conv_lst_m2d_15/while/body/_1/split_1}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_train_function_268982]
#
# Function call stack:
# train_function

# %%
del memory_model

# %%
# Select a random observation, initial trajectory and predicted trajectory
itest = 50
init_traj = 10
pred_traj = data.shape[1] - init_traj
track_MCNet_motion = X_MCNet_motion[itest, :, :, :, :]
track_MCNet_content = X_MCNet_content[itest, :, :, :]
track = data[itest, :init_traj, :, :, :]
print(track.shape)
print(track_MCNet_content.shape)
print(track_MCNet_motion.shape)
# for i in range(pred_traj):
for i in range(10):
  new_pos = model.predict([track_MCNet_motion[None, :, :, :, :], track_MCNet_content[None, :,:,:]])
  track = np.concatenate((track, new_pos), axis=0)
  track_MCNet_content = new_pos[0]
  track_MCNet_motion = np.concatenate((track_MCNet_motion, new_pos), axis=0)
  track_MCNet_motion[-1] = track_MCNet_motion[-1] - track_MCNet_motion[-2]
print("track:", track.shape)
# Out:
# (10, 64, 64, 1)
# (64, 64, 1)
# (9, 64, 64, 1)
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f1b6ba791e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f1b6ba791e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f1b6ba791e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f1b6ba791e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f1b6ba791e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f1b6ba791e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# track: (20, 64, 64, 1)

# %%
# Plot results
true_track = data[itest, :, :, :, 0]

for i in range(20):
    plt.figure(figsize=(10, 5))

    plt.subplot(121)
    if i >= init_traj:
        plt.text(1, 3, 'Prediction', color='w')
    else:
        plt.text(1, 3, 'Initial trajectory', color='w')
    plt.imshow(track[i, :, :, 0])

    plt.subplot(122)
    plt.text(1, 3, 'Ground truth', color='w')
    plt.imshow(true_track[i, :, :])

    plt.savefig('anim_%i.png' % (i+1))
    #files.download('anim_%i.png' % (i+1))
